# %%
import numpy as np
import pandas as pd
import matplotlib 
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import preprocessing, tree
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, roc_curve, auc, plot_confusion_matrix, RocCurveDisplay

from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from collections import Counter
import requests

import keras
import tensorflow
from keras.datasets import mnist
from keras import backend as K
from keras.models import load_model
from tensorflow.keras import optimizers

from sklearn.model_selection import KFold, StratifiedKFold

from preprocessing import *
plt.rcParams["figure.dpi"] = 60

# %% [markdown]
# # Carga del dataset

# %%
df = pd.read_csv("df_train.csv")
X = df.drop(columns=['llovieron_hamburguesas_al_dia_siguiente'])
y = df['llovieron_hamburguesas_al_dia_siguiente']
X_train, X_eval, y_train, y_eval = train_test_split(X, y, random_state=117, test_size=0.1, stratify=y.astype(str))

# %% [markdown]
# # Entrenamiento y seleccion de modelos

# %% [markdown]
# ## Modelo 1
# Primero entrenaremos una red simple, con 13 inputs y utilizando la funcion de activacion tanh en la capa de entrada. Como optimizador utilizaremos SGD.

# %%
X_train1 = preprocessing_redes_2(X_train)
X_train1, X_validation1, y_train1, y_validation1 = train_test_split(X_train1, y_train, random_state=117, test_size=0.3, stratify=y_train)

model1 = Sequential()
model1.add(Dense(13, input_dim=13, activation='tanh'))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer=optimizers.SGD(learning_rate=0.0005), metrics=[tensorflow.keras.metrics.AUC()])

# %%
history1 = model1.fit(X_train1.values, y_train1, epochs=300, verbose=2, validation_data=(X_validation1.values, y_validation1))
# Out:
# Epoch 1/300
# 1970/1970 - 3s - loss: 0.6241 - auc_1: 0.6651 - val_loss: 0.5613 - val_auc_1: 0.7278 - 3s/epoch - 2ms/step
# Epoch 2/300
# 1970/1970 - 3s - loss: 0.5196 - auc_1: 0.7652 - val_loss: 0.4904 - val_auc_1: 0.7847 - 3s/epoch - 1ms/step
# Epoch 3/300
# 1970/1970 - 3s - loss: 0.4671 - auc_1: 0.8020 - val_loss: 0.4512 - val_auc_1: 0.8098 - 3s/epoch - 1ms/step
# Epoch 4/300
# 1970/1970 - 3s - loss: 0.4366 - auc_1: 0.8199 - val_loss: 0.4273 - val_auc_1: 0.8236 - 3s/epoch - 1ms/step
# Epoch 5/300
# 1970/1970 - 3s - loss: 0.4174 - auc_1: 0.8306 - val_loss: 0.4115 - val_auc_1: 0.8322 - 3s/epoch - 1ms/step
# Epoch 6/300
# 1970/1970 - 3s - loss: 0.4045 - auc_1: 0.8371 - val_loss: 0.4007 - val_auc_1: 0.8381 - 3s/epoch - 1ms/step
# Epoch 7/300
# 1970/1970 - 3s - loss: 0.3956 - auc_1: 0.8418 - val_loss: 0.3930 - val_auc_1: 0.8423 - 3s/epoch - 2ms/step
# Epoch 8/300
# 1970/1970 - 3s - loss: 0.3892 - auc_1: 0.8451 - val_loss: 0.3873 - val_auc_1: 0.8455 - 3s/epoch - 1ms/step
# Epoch 9/300
# 1970/1970 - 3s - loss: 0.3844 - auc_1: 0.8476 - val_loss: 0.3830 - val_auc_1: 0.8480 - 3s/epoch - 1ms/step
# Epoch 10/300
# 1970/1970 - 3s - loss: 0.3808 - auc_1: 0.8496 - val_loss: 0.3796 - val_auc_1: 0.8500 - 3s/epoch - 1ms/step
# Epoch 11/300
# 1970/1970 - 3s - loss: 0.3779 - auc_1: 0.8512 - val_loss: 0.3769 - val_auc_1: 0.8515 - 3s/epoch - 1ms/step
# Epoch 12/300
# 1970/1970 - 3s - loss: 0.3757 - auc_1: 0.8525 - val_loss: 0.3747 - val_auc_1: 0.8529 - 3s/epoch - 2ms/step
# Epoch 13/300
# 1970/1970 - 3s - loss: 0.3738 - auc_1: 0.8536 - val_loss: 0.3729 - val_auc_1: 0.8540 - 3s/epoch - 2ms/step
# Epoch 14/300
# 1970/1970 - 3s - loss: 0.3723 - auc_1: 0.8545 - val_loss: 0.3714 - val_auc_1: 0.8549 - 3s/epoch - 2ms/step
# Epoch 15/300
# 1970/1970 - 3s - loss: 0.3711 - auc_1: 0.8552 - val_loss: 0.3701 - val_auc_1: 0.8558 - 3s/epoch - 1ms/step
# Epoch 16/300
# 1970/1970 - 3s - loss: 0.3700 - auc_1: 0.8559 - val_loss: 0.3690 - val_auc_1: 0.8566 - 3s/epoch - 1ms/step
# Epoch 17/300
# 1970/1970 - 3s - loss: 0.3691 - auc_1: 0.8565 - val_loss: 0.3681 - val_auc_1: 0.8572 - 3s/epoch - 1ms/step
# Epoch 18/300
# 1970/1970 - 3s - loss: 0.3683 - auc_1: 0.8570 - val_loss: 0.3672 - val_auc_1: 0.8577 - 3s/epoch - 1ms/step
# Epoch 19/300
# 1970/1970 - 3s - loss: 0.3675 - auc_1: 0.8575 - val_loss: 0.3665 - val_auc_1: 0.8583 - 3s/epoch - 1ms/step
# Epoch 20/300
# 1970/1970 - 3s - loss: 0.3669 - auc_1: 0.8579 - val_loss: 0.3658 - val_auc_1: 0.8586 - 3s/epoch - 1ms/step
# Epoch 21/300
# 1970/1970 - 3s - loss: 0.3664 - auc_1: 0.8583 - val_loss: 0.3652 - val_auc_1: 0.8591 - 3s/epoch - 1ms/step
# Epoch 22/300
# 1970/1970 - 3s - loss: 0.3659 - auc_1: 0.8586 - val_loss: 0.3646 - val_auc_1: 0.8594 - 3s/epoch - 1ms/step
# Epoch 23/300
# 1970/1970 - 3s - loss: 0.3654 - auc_1: 0.8590 - val_loss: 0.3641 - val_auc_1: 0.8598 - 3s/epoch - 1ms/step
# Epoch 24/300
# 1970/1970 - 3s - loss: 0.3650 - auc_1: 0.8592 - val_loss: 0.3637 - val_auc_1: 0.8601 - 3s/epoch - 1ms/step
# Epoch 25/300
# 1970/1970 - 3s - loss: 0.3646 - auc_1: 0.8595 - val_loss: 0.3633 - val_auc_1: 0.8605 - 3s/epoch - 1ms/step
# Epoch 26/300
# 1970/1970 - 3s - loss: 0.3643 - auc_1: 0.8597 - val_loss: 0.3629 - val_auc_1: 0.8607 - 3s/epoch - 1ms/step
# Epoch 27/300
# 1970/1970 - 3s - loss: 0.3640 - auc_1: 0.8599 - val_loss: 0.3625 - val_auc_1: 0.8610 - 3s/epoch - 1ms/step
# Epoch 28/300
# 1970/1970 - 3s - loss: 0.3637 - auc_1: 0.8601 - val_loss: 0.3622 - val_auc_1: 0.8612 - 3s/epoch - 1ms/step
# Epoch 29/300
# 1970/1970 - 3s - loss: 0.3634 - auc_1: 0.8603 - val_loss: 0.3619 - val_auc_1: 0.8614 - 3s/epoch - 1ms/step
# Epoch 30/300
# 1970/1970 - 3s - loss: 0.3631 - auc_1: 0.8605 - val_loss: 0.3616 - val_auc_1: 0.8616 - 3s/epoch - 1ms/step
# Epoch 31/300
# 1970/1970 - 3s - loss: 0.3629 - auc_1: 0.8606 - val_loss: 0.3613 - val_auc_1: 0.8618 - 3s/epoch - 2ms/step
# Epoch 32/300
# 1970/1970 - 3s - loss: 0.3627 - auc_1: 0.8609 - val_loss: 0.3611 - val_auc_1: 0.8619 - 3s/epoch - 1ms/step
# Epoch 33/300
# 1970/1970 - 3s - loss: 0.3624 - auc_1: 0.8610 - val_loss: 0.3608 - val_auc_1: 0.8621 - 3s/epoch - 1ms/step
# Epoch 34/300
# 1970/1970 - 3s - loss: 0.3622 - auc_1: 0.8611 - val_loss: 0.3606 - val_auc_1: 0.8622 - 3s/epoch - 1ms/step
# Epoch 35/300
# 1970/1970 - 3s - loss: 0.3620 - auc_1: 0.8612 - val_loss: 0.3604 - val_auc_1: 0.8624 - 3s/epoch - 1ms/step
# Epoch 36/300
# 1970/1970 - 3s - loss: 0.3619 - auc_1: 0.8614 - val_loss: 0.3602 - val_auc_1: 0.8626 - 3s/epoch - 1ms/step
# Epoch 37/300
# 1970/1970 - 3s - loss: 0.3617 - auc_1: 0.8615 - val_loss: 0.3600 - val_auc_1: 0.8627 - 3s/epoch - 1ms/step
# Epoch 38/300
# 1970/1970 - 3s - loss: 0.3615 - auc_1: 0.8617 - val_loss: 0.3598 - val_auc_1: 0.8629 - 3s/epoch - 1ms/step
# Epoch 39/300
# 1970/1970 - 3s - loss: 0.3614 - auc_1: 0.8618 - val_loss: 0.3596 - val_auc_1: 0.8630 - 3s/epoch - 1ms/step
# Epoch 40/300
# 1970/1970 - 3s - loss: 0.3612 - auc_1: 0.8619 - val_loss: 0.3595 - val_auc_1: 0.8631 - 3s/epoch - 1ms/step
# Epoch 41/300
# 1970/1970 - 3s - loss: 0.3610 - auc_1: 0.8620 - val_loss: 0.3593 - val_auc_1: 0.8632 - 3s/epoch - 1ms/step
# Epoch 42/300
# 1970/1970 - 3s - loss: 0.3609 - auc_1: 0.8621 - val_loss: 0.3591 - val_auc_1: 0.8633 - 3s/epoch - 1ms/step
# Epoch 43/300
# 1970/1970 - 3s - loss: 0.3608 - auc_1: 0.8623 - val_loss: 0.3590 - val_auc_1: 0.8634 - 3s/epoch - 1ms/step
# Epoch 44/300
# 1970/1970 - 3s - loss: 0.3606 - auc_1: 0.8623 - val_loss: 0.3589 - val_auc_1: 0.8635 - 3s/epoch - 1ms/step
# Epoch 45/300
# 1970/1970 - 3s - loss: 0.3605 - auc_1: 0.8624 - val_loss: 0.3587 - val_auc_1: 0.8636 - 3s/epoch - 1ms/step
# Epoch 46/300
# 1970/1970 - 3s - loss: 0.3604 - auc_1: 0.8625 - val_loss: 0.3586 - val_auc_1: 0.8637 - 3s/epoch - 1ms/step
# Epoch 47/300
# 1970/1970 - 3s - loss: 0.3603 - auc_1: 0.8626 - val_loss: 0.3584 - val_auc_1: 0.8638 - 3s/epoch - 1ms/step
# Epoch 48/300
# 1970/1970 - 3s - loss: 0.3601 - auc_1: 0.8627 - val_loss: 0.3583 - val_auc_1: 0.8639 - 3s/epoch - 1ms/step
# Epoch 49/300
# 1970/1970 - 3s - loss: 0.3600 - auc_1: 0.8628 - val_loss: 0.3582 - val_auc_1: 0.8640 - 3s/epoch - 1ms/step
# Epoch 50/300
# 1970/1970 - 3s - loss: 0.3599 - auc_1: 0.8629 - val_loss: 0.3581 - val_auc_1: 0.8641 - 3s/epoch - 1ms/step
# Epoch 51/300
# 1970/1970 - 3s - loss: 0.3598 - auc_1: 0.8630 - val_loss: 0.3580 - val_auc_1: 0.8642 - 3s/epoch - 2ms/step
# Epoch 52/300
# 1970/1970 - 3s - loss: 0.3597 - auc_1: 0.8631 - val_loss: 0.3579 - val_auc_1: 0.8643 - 3s/epoch - 2ms/step
# Epoch 53/300
# 1970/1970 - 3s - loss: 0.3596 - auc_1: 0.8631 - val_loss: 0.3578 - val_auc_1: 0.8644 - 3s/epoch - 1ms/step
# Epoch 54/300
# 1970/1970 - 3s - loss: 0.3595 - auc_1: 0.8632 - val_loss: 0.3577 - val_auc_1: 0.8644 - 3s/epoch - 1ms/step
# Epoch 55/300
# 1970/1970 - 3s - loss: 0.3594 - auc_1: 0.8633 - val_loss: 0.3576 - val_auc_1: 0.8645 - 3s/epoch - 1ms/step
# Epoch 56/300
# 1970/1970 - 3s - loss: 0.3593 - auc_1: 0.8634 - val_loss: 0.3575 - val_auc_1: 0.8645 - 3s/epoch - 1ms/step
# Epoch 57/300
# 1970/1970 - 3s - loss: 0.3592 - auc_1: 0.8634 - val_loss: 0.3574 - val_auc_1: 0.8646 - 3s/epoch - 1ms/step
# Epoch 58/300
# 1970/1970 - 3s - loss: 0.3591 - auc_1: 0.8635 - val_loss: 0.3573 - val_auc_1: 0.8647 - 3s/epoch - 1ms/step
# Epoch 59/300
# 1970/1970 - 3s - loss: 0.3591 - auc_1: 0.8636 - val_loss: 0.3572 - val_auc_1: 0.8647 - 3s/epoch - 1ms/step
# Epoch 60/300
# 1970/1970 - 3s - loss: 0.3590 - auc_1: 0.8636 - val_loss: 0.3571 - val_auc_1: 0.8648 - 3s/epoch - 1ms/step
# Epoch 61/300
# 1970/1970 - 3s - loss: 0.3589 - auc_1: 0.8637 - val_loss: 0.3570 - val_auc_1: 0.8649 - 3s/epoch - 1ms/step
# Epoch 62/300
# 1970/1970 - 3s - loss: 0.3588 - auc_1: 0.8638 - val_loss: 0.3569 - val_auc_1: 0.8649 - 3s/epoch - 1ms/step
# Epoch 63/300
# 1970/1970 - 3s - loss: 0.3587 - auc_1: 0.8638 - val_loss: 0.3568 - val_auc_1: 0.8650 - 3s/epoch - 1ms/step
# Epoch 64/300
# 1970/1970 - 3s - loss: 0.3586 - auc_1: 0.8639 - val_loss: 0.3567 - val_auc_1: 0.8650 - 3s/epoch - 1ms/step
# Epoch 65/300
# 1970/1970 - 3s - loss: 0.3586 - auc_1: 0.8639 - val_loss: 0.3567 - val_auc_1: 0.8651 - 3s/epoch - 1ms/step
# Epoch 66/300
# 1970/1970 - 3s - loss: 0.3585 - auc_1: 0.8640 - val_loss: 0.3566 - val_auc_1: 0.8652 - 3s/epoch - 1ms/step
# Epoch 67/300
# 1970/1970 - 3s - loss: 0.3584 - auc_1: 0.8640 - val_loss: 0.3565 - val_auc_1: 0.8653 - 3s/epoch - 1ms/step
# Epoch 68/300
# 1970/1970 - 3s - loss: 0.3583 - auc_1: 0.8641 - val_loss: 0.3564 - val_auc_1: 0.8654 - 3s/epoch - 1ms/step
# Epoch 69/300
# 1970/1970 - 3s - loss: 0.3583 - auc_1: 0.8642 - val_loss: 0.3564 - val_auc_1: 0.8654 - 3s/epoch - 1ms/step
# Epoch 70/300
# 1970/1970 - 3s - loss: 0.3582 - auc_1: 0.8642 - val_loss: 0.3563 - val_auc_1: 0.8655 - 3s/epoch - 1ms/step
# Epoch 71/300
# 1970/1970 - 3s - loss: 0.3581 - auc_1: 0.8643 - val_loss: 0.3562 - val_auc_1: 0.8655 - 3s/epoch - 1ms/step
# Epoch 72/300
# 1970/1970 - 3s - loss: 0.3581 - auc_1: 0.8643 - val_loss: 0.3562 - val_auc_1: 0.8656 - 3s/epoch - 1ms/step
# Epoch 73/300
# 1970/1970 - 3s - loss: 0.3580 - auc_1: 0.8644 - val_loss: 0.3561 - val_auc_1: 0.8656 - 3s/epoch - 1ms/step
# Epoch 74/300
# 1970/1970 - 3s - loss: 0.3579 - auc_1: 0.8644 - val_loss: 0.3560 - val_auc_1: 0.8656 - 3s/epoch - 1ms/step
# Epoch 75/300
# 1970/1970 - 3s - loss: 0.3579 - auc_1: 0.8645 - val_loss: 0.3560 - val_auc_1: 0.8657 - 3s/epoch - 1ms/step
# Epoch 76/300
# 1970/1970 - 3s - loss: 0.3578 - auc_1: 0.8645 - val_loss: 0.3559 - val_auc_1: 0.8657 - 3s/epoch - 1ms/step
# Epoch 77/300
# 1970/1970 - 3s - loss: 0.3577 - auc_1: 0.8646 - val_loss: 0.3558 - val_auc_1: 0.8658 - 3s/epoch - 1ms/step
# Epoch 78/300
# 1970/1970 - 3s - loss: 0.3577 - auc_1: 0.8646 - val_loss: 0.3558 - val_auc_1: 0.8658 - 3s/epoch - 1ms/step
# Epoch 79/300
# 1970/1970 - 3s - loss: 0.3576 - auc_1: 0.8647 - val_loss: 0.3557 - val_auc_1: 0.8658 - 3s/epoch - 1ms/step
# Epoch 80/300
# 1970/1970 - 3s - loss: 0.3576 - auc_1: 0.8647 - val_loss: 0.3556 - val_auc_1: 0.8659 - 3s/epoch - 1ms/step
# Epoch 81/300
# 1970/1970 - 3s - loss: 0.3575 - auc_1: 0.8648 - val_loss: 0.3556 - val_auc_1: 0.8659 - 3s/epoch - 1ms/step
# Epoch 82/300
# 1970/1970 - 3s - loss: 0.3575 - auc_1: 0.8648 - val_loss: 0.3555 - val_auc_1: 0.8660 - 3s/epoch - 1ms/step
# Epoch 83/300
# 1970/1970 - 3s - loss: 0.3574 - auc_1: 0.8649 - val_loss: 0.3555 - val_auc_1: 0.8661 - 3s/epoch - 1ms/step
# Epoch 84/300
# 1970/1970 - 3s - loss: 0.3573 - auc_1: 0.8649 - val_loss: 0.3554 - val_auc_1: 0.8661 - 3s/epoch - 1ms/step
# Epoch 85/300
# 1970/1970 - 3s - loss: 0.3573 - auc_1: 0.8649 - val_loss: 0.3554 - val_auc_1: 0.8661 - 3s/epoch - 1ms/step
# Epoch 86/300
# 1970/1970 - 3s - loss: 0.3572 - auc_1: 0.8650 - val_loss: 0.3553 - val_auc_1: 0.8662 - 3s/epoch - 1ms/step
# Epoch 87/300
# 1970/1970 - 3s - loss: 0.3572 - auc_1: 0.8650 - val_loss: 0.3552 - val_auc_1: 0.8662 - 3s/epoch - 1ms/step
# Epoch 88/300
# 1970/1970 - 3s - loss: 0.3571 - auc_1: 0.8651 - val_loss: 0.3552 - val_auc_1: 0.8663 - 3s/epoch - 1ms/step
# Epoch 89/300
# 1970/1970 - 3s - loss: 0.3571 - auc_1: 0.8651 - val_loss: 0.3551 - val_auc_1: 0.8663 - 3s/epoch - 1ms/step
# Epoch 90/300
# 1970/1970 - 3s - loss: 0.3570 - auc_1: 0.8651 - val_loss: 0.3551 - val_auc_1: 0.8664 - 3s/epoch - 1ms/step
# Epoch 91/300
# 1970/1970 - 3s - loss: 0.3570 - auc_1: 0.8652 - val_loss: 0.3550 - val_auc_1: 0.8664 - 3s/epoch - 1ms/step
# Epoch 92/300
# 1970/1970 - 3s - loss: 0.3569 - auc_1: 0.8652 - val_loss: 0.3550 - val_auc_1: 0.8664 - 3s/epoch - 1ms/step
# Epoch 93/300
# 1970/1970 - 3s - loss: 0.3569 - auc_1: 0.8653 - val_loss: 0.3549 - val_auc_1: 0.8665 - 3s/epoch - 1ms/step
# Epoch 94/300
# 1970/1970 - 3s - loss: 0.3568 - auc_1: 0.8653 - val_loss: 0.3549 - val_auc_1: 0.8665 - 3s/epoch - 1ms/step
# Epoch 95/300
# 1970/1970 - 3s - loss: 0.3568 - auc_1: 0.8653 - val_loss: 0.3548 - val_auc_1: 0.8666 - 3s/epoch - 1ms/step
# Epoch 96/300
# 1970/1970 - 3s - loss: 0.3567 - auc_1: 0.8654 - val_loss: 0.3548 - val_auc_1: 0.8666 - 3s/epoch - 1ms/step
# Epoch 97/300
# 1970/1970 - 3s - loss: 0.3567 - auc_1: 0.8654 - val_loss: 0.3548 - val_auc_1: 0.8666 - 3s/epoch - 1ms/step
# Epoch 98/300
# 1970/1970 - 3s - loss: 0.3567 - auc_1: 0.8655 - val_loss: 0.3547 - val_auc_1: 0.8667 - 3s/epoch - 1ms/step
# Epoch 99/300
# 1970/1970 - 3s - loss: 0.3566 - auc_1: 0.8655 - val_loss: 0.3547 - val_auc_1: 0.8666 - 3s/epoch - 1ms/step
# Epoch 100/300
# 1970/1970 - 3s - loss: 0.3566 - auc_1: 0.8655 - val_loss: 0.3546 - val_auc_1: 0.8667 - 3s/epoch - 1ms/step
# Epoch 101/300
# 1970/1970 - 3s - loss: 0.3565 - auc_1: 0.8656 - val_loss: 0.3546 - val_auc_1: 0.8668 - 3s/epoch - 1ms/step
# Epoch 102/300
# 1970/1970 - 3s - loss: 0.3565 - auc_1: 0.8656 - val_loss: 0.3545 - val_auc_1: 0.8668 - 3s/epoch - 1ms/step
# Epoch 103/300
# 1970/1970 - 3s - loss: 0.3564 - auc_1: 0.8657 - val_loss: 0.3545 - val_auc_1: 0.8669 - 3s/epoch - 1ms/step
# Epoch 104/300
# 1970/1970 - 3s - loss: 0.3564 - auc_1: 0.8657 - val_loss: 0.3545 - val_auc_1: 0.8669 - 3s/epoch - 1ms/step
# Epoch 105/300
# 1970/1970 - 3s - loss: 0.3564 - auc_1: 0.8657 - val_loss: 0.3544 - val_auc_1: 0.8670 - 3s/epoch - 1ms/step
# Epoch 106/300
# 1970/1970 - 3s - loss: 0.3563 - auc_1: 0.8657 - val_loss: 0.3544 - val_auc_1: 0.8670 - 3s/epoch - 1ms/step
# Epoch 107/300
# 1970/1970 - 3s - loss: 0.3563 - auc_1: 0.8658 - val_loss: 0.3543 - val_auc_1: 0.8670 - 3s/epoch - 1ms/step
# Epoch 108/300
# 1970/1970 - 3s - loss: 0.3562 - auc_1: 0.8658 - val_loss: 0.3543 - val_auc_1: 0.8671 - 3s/epoch - 1ms/step
# Epoch 109/300
# 1970/1970 - 3s - loss: 0.3562 - auc_1: 0.8658 - val_loss: 0.3543 - val_auc_1: 0.8671 - 3s/epoch - 1ms/step
# Epoch 110/300
# 1970/1970 - 3s - loss: 0.3562 - auc_1: 0.8659 - val_loss: 0.3542 - val_auc_1: 0.8671 - 3s/epoch - 1ms/step
# Epoch 111/300
# 1970/1970 - 3s - loss: 0.3561 - auc_1: 0.8659 - val_loss: 0.3542 - val_auc_1: 0.8671 - 3s/epoch - 1ms/step
# Epoch 112/300
# 1970/1970 - 3s - loss: 0.3561 - auc_1: 0.8659 - val_loss: 0.3541 - val_auc_1: 0.8672 - 3s/epoch - 1ms/step
# Epoch 113/300
# 1970/1970 - 3s - loss: 0.3560 - auc_1: 0.8660 - val_loss: 0.3541 - val_auc_1: 0.8672 - 3s/epoch - 1ms/step
# Epoch 114/300
# 1970/1970 - 3s - loss: 0.3560 - auc_1: 0.8660 - val_loss: 0.3541 - val_auc_1: 0.8672 - 3s/epoch - 1ms/step
# Epoch 115/300
# 1970/1970 - 3s - loss: 0.3560 - auc_1: 0.8660 - val_loss: 0.3540 - val_auc_1: 0.8672 - 3s/epoch - 2ms/step
# Epoch 116/300
# 1970/1970 - 3s - loss: 0.3559 - auc_1: 0.8661 - val_loss: 0.3540 - val_auc_1: 0.8673 - 3s/epoch - 1ms/step
# Epoch 117/300
# 1970/1970 - 3s - loss: 0.3559 - auc_1: 0.8661 - val_loss: 0.3539 - val_auc_1: 0.8673 - 3s/epoch - 2ms/step
# Epoch 118/300
# 1970/1970 - 3s - loss: 0.3559 - auc_1: 0.8661 - val_loss: 0.3539 - val_auc_1: 0.8673 - 3s/epoch - 1ms/step
# Epoch 119/300
# 1970/1970 - 3s - loss: 0.3558 - auc_1: 0.8661 - val_loss: 0.3539 - val_auc_1: 0.8674 - 3s/epoch - 1ms/step
# Epoch 120/300
# 1970/1970 - 3s - loss: 0.3558 - auc_1: 0.8662 - val_loss: 0.3538 - val_auc_1: 0.8674 - 3s/epoch - 1ms/step
# Epoch 121/300
# 1970/1970 - 3s - loss: 0.3558 - auc_1: 0.8662 - val_loss: 0.3538 - val_auc_1: 0.8674 - 3s/epoch - 1ms/step
# Epoch 122/300
# 1970/1970 - 3s - loss: 0.3557 - auc_1: 0.8662 - val_loss: 0.3538 - val_auc_1: 0.8675 - 3s/epoch - 1ms/step
# Epoch 123/300
# 1970/1970 - 3s - loss: 0.3557 - auc_1: 0.8662 - val_loss: 0.3537 - val_auc_1: 0.8675 - 3s/epoch - 1ms/step
# Epoch 124/300
# 1970/1970 - 3s - loss: 0.3557 - auc_1: 0.8662 - val_loss: 0.3537 - val_auc_1: 0.8675 - 3s/epoch - 1ms/step
# Epoch 125/300
# 1970/1970 - 3s - loss: 0.3556 - auc_1: 0.8663 - val_loss: 0.3537 - val_auc_1: 0.8675 - 3s/epoch - 1ms/step
# Epoch 126/300
# 1970/1970 - 3s - loss: 0.3556 - auc_1: 0.8663 - val_loss: 0.3536 - val_auc_1: 0.8676 - 3s/epoch - 1ms/step
# Epoch 127/300
# 1970/1970 - 3s - loss: 0.3556 - auc_1: 0.8663 - val_loss: 0.3536 - val_auc_1: 0.8675 - 3s/epoch - 1ms/step
# Epoch 128/300
# 1970/1970 - 3s - loss: 0.3555 - auc_1: 0.8664 - val_loss: 0.3535 - val_auc_1: 0.8676 - 3s/epoch - 1ms/step
# Epoch 129/300
# 1970/1970 - 3s - loss: 0.3555 - auc_1: 0.8664 - val_loss: 0.3535 - val_auc_1: 0.8676 - 3s/epoch - 1ms/step
# Epoch 130/300
# 1970/1970 - 3s - loss: 0.3555 - auc_1: 0.8664 - val_loss: 0.3535 - val_auc_1: 0.8677 - 3s/epoch - 1ms/step
# Epoch 131/300
# 1970/1970 - 3s - loss: 0.3554 - auc_1: 0.8665 - val_loss: 0.3535 - val_auc_1: 0.8677 - 3s/epoch - 2ms/step
# Epoch 132/300
# 1970/1970 - 4s - loss: 0.3554 - auc_1: 0.8664 - val_loss: 0.3534 - val_auc_1: 0.8677 - 4s/epoch - 2ms/step
# Epoch 133/300
# 1970/1970 - 3s - loss: 0.3554 - auc_1: 0.8665 - val_loss: 0.3534 - val_auc_1: 0.8677 - 3s/epoch - 2ms/step
# Epoch 134/300
# 1970/1970 - 3s - loss: 0.3553 - auc_1: 0.8665 - val_loss: 0.3534 - val_auc_1: 0.8678 - 3s/epoch - 2ms/step
# Epoch 135/300
# 1970/1970 - 3s - loss: 0.3553 - auc_1: 0.8666 - val_loss: 0.3533 - val_auc_1: 0.8678 - 3s/epoch - 2ms/step
# Epoch 136/300
# 1970/1970 - 3s - loss: 0.3553 - auc_1: 0.8666 - val_loss: 0.3533 - val_auc_1: 0.8678 - 3s/epoch - 2ms/step
# Epoch 137/300
# 1970/1970 - 4s - loss: 0.3552 - auc_1: 0.8666 - val_loss: 0.3533 - val_auc_1: 0.8679 - 4s/epoch - 2ms/step
# Epoch 138/300
# 1970/1970 - 3s - loss: 0.3552 - auc_1: 0.8666 - val_loss: 0.3532 - val_auc_1: 0.8679 - 3s/epoch - 1ms/step
# Epoch 139/300
# 1970/1970 - 3s - loss: 0.3552 - auc_1: 0.8667 - val_loss: 0.3532 - val_auc_1: 0.8679 - 3s/epoch - 1ms/step
# Epoch 140/300
# 1970/1970 - 3s - loss: 0.3551 - auc_1: 0.8667 - val_loss: 0.3532 - val_auc_1: 0.8679 - 3s/epoch - 1ms/step
# Epoch 141/300
# 1970/1970 - 3s - loss: 0.3551 - auc_1: 0.8667 - val_loss: 0.3532 - val_auc_1: 0.8680 - 3s/epoch - 1ms/step
# Epoch 142/300
# 1970/1970 - 3s - loss: 0.3551 - auc_1: 0.8667 - val_loss: 0.3531 - val_auc_1: 0.8680 - 3s/epoch - 1ms/step
# Epoch 143/300
# 1970/1970 - 3s - loss: 0.3551 - auc_1: 0.8667 - val_loss: 0.3531 - val_auc_1: 0.8680 - 3s/epoch - 1ms/step
# Epoch 144/300
# 1970/1970 - 3s - loss: 0.3550 - auc_1: 0.8668 - val_loss: 0.3531 - val_auc_1: 0.8680 - 3s/epoch - 1ms/step
# Epoch 145/300
# 1970/1970 - 3s - loss: 0.3550 - auc_1: 0.8668 - val_loss: 0.3530 - val_auc_1: 0.8680 - 3s/epoch - 1ms/step
# Epoch 146/300
# 1970/1970 - 3s - loss: 0.3550 - auc_1: 0.8668 - val_loss: 0.3530 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 147/300
# 1970/1970 - 3s - loss: 0.3549 - auc_1: 0.8668 - val_loss: 0.3530 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 148/300
# 1970/1970 - 3s - loss: 0.3549 - auc_1: 0.8669 - val_loss: 0.3529 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 149/300
# 1970/1970 - 3s - loss: 0.3549 - auc_1: 0.8669 - val_loss: 0.3529 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 150/300
# 1970/1970 - 3s - loss: 0.3549 - auc_1: 0.8669 - val_loss: 0.3529 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 151/300
# 1970/1970 - 3s - loss: 0.3548 - auc_1: 0.8670 - val_loss: 0.3528 - val_auc_1: 0.8681 - 3s/epoch - 1ms/step
# Epoch 152/300
# 1970/1970 - 3s - loss: 0.3548 - auc_1: 0.8670 - val_loss: 0.3528 - val_auc_1: 0.8682 - 3s/epoch - 1ms/step
# Epoch 153/300
# 1970/1970 - 3s - loss: 0.3548 - auc_1: 0.8670 - val_loss: 0.3528 - val_auc_1: 0.8682 - 3s/epoch - 1ms/step
# Epoch 154/300
# 1970/1970 - 3s - loss: 0.3547 - auc_1: 0.8670 - val_loss: 0.3528 - val_auc_1: 0.8682 - 3s/epoch - 1ms/step
# Epoch 155/300
# 1970/1970 - 3s - loss: 0.3547 - auc_1: 0.8670 - val_loss: 0.3527 - val_auc_1: 0.8682 - 3s/epoch - 1ms/step
# Epoch 156/300
# 1970/1970 - 3s - loss: 0.3547 - auc_1: 0.8671 - val_loss: 0.3527 - val_auc_1: 0.8683 - 3s/epoch - 1ms/step
# Epoch 157/300
# 1970/1970 - 3s - loss: 0.3547 - auc_1: 0.8671 - val_loss: 0.3527 - val_auc_1: 0.8683 - 3s/epoch - 1ms/step
# Epoch 158/300
# 1970/1970 - 3s - loss: 0.3546 - auc_1: 0.8670 - val_loss: 0.3527 - val_auc_1: 0.8683 - 3s/epoch - 1ms/step
# Epoch 159/300
# 1970/1970 - 3s - loss: 0.3546 - auc_1: 0.8671 - val_loss: 0.3526 - val_auc_1: 0.8683 - 3s/epoch - 1ms/step
# Epoch 160/300
# 1970/1970 - 3s - loss: 0.3546 - auc_1: 0.8671 - val_loss: 0.3526 - val_auc_1: 0.8683 - 3s/epoch - 1ms/step
# Epoch 161/300
# 1970/1970 - 3s - loss: 0.3545 - auc_1: 0.8672 - val_loss: 0.3526 - val_auc_1: 0.8684 - 3s/epoch - 1ms/step
# Epoch 162/300
# 1970/1970 - 3s - loss: 0.3545 - auc_1: 0.8672 - val_loss: 0.3525 - val_auc_1: 0.8684 - 3s/epoch - 1ms/step
# Epoch 163/300
# 1970/1970 - 3s - loss: 0.3545 - auc_1: 0.8672 - val_loss: 0.3525 - val_auc_1: 0.8684 - 3s/epoch - 1ms/step
# Epoch 164/300
# 1970/1970 - 3s - loss: 0.3545 - auc_1: 0.8672 - val_loss: 0.3525 - val_auc_1: 0.8684 - 3s/epoch - 1ms/step
# Epoch 165/300
# 1970/1970 - 3s - loss: 0.3544 - auc_1: 0.8673 - val_loss: 0.3525 - val_auc_1: 0.8685 - 3s/epoch - 1ms/step
# Epoch 166/300
# 1970/1970 - 3s - loss: 0.3544 - auc_1: 0.8673 - val_loss: 0.3524 - val_auc_1: 0.8685 - 3s/epoch - 1ms/step
# Epoch 167/300
# 1970/1970 - 3s - loss: 0.3544 - auc_1: 0.8673 - val_loss: 0.3524 - val_auc_1: 0.8685 - 3s/epoch - 1ms/step
# Epoch 168/300
# 1970/1970 - 3s - loss: 0.3544 - auc_1: 0.8673 - val_loss: 0.3524 - val_auc_1: 0.8685 - 3s/epoch - 1ms/step
# Epoch 169/300
# 1970/1970 - 3s - loss: 0.3543 - auc_1: 0.8673 - val_loss: 0.3523 - val_auc_1: 0.8685 - 3s/epoch - 1ms/step
# Epoch 170/300
# 1970/1970 - 3s - loss: 0.3543 - auc_1: 0.8674 - val_loss: 0.3523 - val_auc_1: 0.8686 - 3s/epoch - 1ms/step
# Epoch 171/300
# 1970/1970 - 3s - loss: 0.3543 - auc_1: 0.8674 - val_loss: 0.3523 - val_auc_1: 0.8686 - 3s/epoch - 1ms/step
# Epoch 172/300
# 1970/1970 - 3s - loss: 0.3543 - auc_1: 0.8674 - val_loss: 0.3523 - val_auc_1: 0.8686 - 3s/epoch - 1ms/step
# Epoch 173/300
# 1970/1970 - 3s - loss: 0.3542 - auc_1: 0.8674 - val_loss: 0.3522 - val_auc_1: 0.8687 - 3s/epoch - 1ms/step
# Epoch 174/300
# 1970/1970 - 3s - loss: 0.3542 - auc_1: 0.8675 - val_loss: 0.3522 - val_auc_1: 0.8687 - 3s/epoch - 1ms/step
# Epoch 175/300
# 1970/1970 - 3s - loss: 0.3542 - auc_1: 0.8675 - val_loss: 0.3522 - val_auc_1: 0.8687 - 3s/epoch - 1ms/step
# Epoch 176/300
# 1970/1970 - 3s - loss: 0.3542 - auc_1: 0.8675 - val_loss: 0.3522 - val_auc_1: 0.8688 - 3s/epoch - 1ms/step
# Epoch 177/300
# 1970/1970 - 3s - loss: 0.3541 - auc_1: 0.8675 - val_loss: 0.3521 - val_auc_1: 0.8688 - 3s/epoch - 1ms/step
# Epoch 178/300
# 1970/1970 - 3s - loss: 0.3541 - auc_1: 0.8675 - val_loss: 0.3521 - val_auc_1: 0.8688 - 3s/epoch - 1ms/step
# Epoch 179/300
# 1970/1970 - 3s - loss: 0.3541 - auc_1: 0.8676 - val_loss: 0.3521 - val_auc_1: 0.8688 - 3s/epoch - 1ms/step
# Epoch 180/300
# 1970/1970 - 3s - loss: 0.3540 - auc_1: 0.8676 - val_loss: 0.3521 - val_auc_1: 0.8689 - 3s/epoch - 1ms/step
# Epoch 181/300
# 1970/1970 - 3s - loss: 0.3540 - auc_1: 0.8676 - val_loss: 0.3520 - val_auc_1: 0.8689 - 3s/epoch - 1ms/step
# Epoch 182/300
# 1970/1970 - 3s - loss: 0.3540 - auc_1: 0.8676 - val_loss: 0.3520 - val_auc_1: 0.8689 - 3s/epoch - 1ms/step
# Epoch 183/300
# 1970/1970 - 3s - loss: 0.3540 - auc_1: 0.8676 - val_loss: 0.3520 - val_auc_1: 0.8689 - 3s/epoch - 1ms/step
# Epoch 184/300
# 1970/1970 - 3s - loss: 0.3539 - auc_1: 0.8677 - val_loss: 0.3519 - val_auc_1: 0.8690 - 3s/epoch - 1ms/step
# Epoch 185/300
# 1970/1970 - 3s - loss: 0.3539 - auc_1: 0.8677 - val_loss: 0.3519 - val_auc_1: 0.8689 - 3s/epoch - 1ms/step
# Epoch 186/300
# 1970/1970 - 3s - loss: 0.3539 - auc_1: 0.8677 - val_loss: 0.3519 - val_auc_1: 0.8690 - 3s/epoch - 1ms/step
# Epoch 187/300
# 1970/1970 - 3s - loss: 0.3539 - auc_1: 0.8677 - val_loss: 0.3519 - val_auc_1: 0.8691 - 3s/epoch - 1ms/step
# Epoch 188/300
# 1970/1970 - 3s - loss: 0.3538 - auc_1: 0.8677 - val_loss: 0.3518 - val_auc_1: 0.8690 - 3s/epoch - 1ms/step
# Epoch 189/300
# 1970/1970 - 3s - loss: 0.3538 - auc_1: 0.8677 - val_loss: 0.3518 - val_auc_1: 0.8691 - 3s/epoch - 1ms/step
# Epoch 190/300
# 1970/1970 - 3s - loss: 0.3538 - auc_1: 0.8678 - val_loss: 0.3518 - val_auc_1: 0.8690 - 3s/epoch - 1ms/step
# Epoch 191/300
# 1970/1970 - 3s - loss: 0.3538 - auc_1: 0.8678 - val_loss: 0.3518 - val_auc_1: 0.8691 - 3s/epoch - 1ms/step
# Epoch 192/300
# 1970/1970 - 3s - loss: 0.3537 - auc_1: 0.8678 - val_loss: 0.3518 - val_auc_1: 0.8691 - 3s/epoch - 1ms/step
# Epoch 193/300
# 1970/1970 - 3s - loss: 0.3537 - auc_1: 0.8678 - val_loss: 0.3517 - val_auc_1: 0.8692 - 3s/epoch - 1ms/step
# Epoch 194/300
# 1970/1970 - 3s - loss: 0.3537 - auc_1: 0.8679 - val_loss: 0.3517 - val_auc_1: 0.8691 - 3s/epoch - 1ms/step
# Epoch 195/300
# 1970/1970 - 3s - loss: 0.3537 - auc_1: 0.8679 - val_loss: 0.3517 - val_auc_1: 0.8692 - 3s/epoch - 1ms/step
# Epoch 196/300
# 1970/1970 - 3s - loss: 0.3537 - auc_1: 0.8679 - val_loss: 0.3517 - val_auc_1: 0.8692 - 3s/epoch - 1ms/step
# Epoch 197/300
# 1970/1970 - 3s - loss: 0.3536 - auc_1: 0.8679 - val_loss: 0.3516 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 198/300
# 1970/1970 - 3s - loss: 0.3536 - auc_1: 0.8679 - val_loss: 0.3516 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 199/300
# 1970/1970 - 3s - loss: 0.3536 - auc_1: 0.8679 - val_loss: 0.3516 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 200/300
# 1970/1970 - 3s - loss: 0.3536 - auc_1: 0.8679 - val_loss: 0.3515 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 201/300
# 1970/1970 - 3s - loss: 0.3535 - auc_1: 0.8680 - val_loss: 0.3515 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 202/300
# 1970/1970 - 3s - loss: 0.3535 - auc_1: 0.8680 - val_loss: 0.3515 - val_auc_1: 0.8693 - 3s/epoch - 1ms/step
# Epoch 203/300
# 1970/1970 - 3s - loss: 0.3535 - auc_1: 0.8680 - val_loss: 0.3515 - val_auc_1: 0.8694 - 3s/epoch - 1ms/step
# Epoch 204/300
# 1970/1970 - 3s - loss: 0.3535 - auc_1: 0.8681 - val_loss: 0.3514 - val_auc_1: 0.8694 - 3s/epoch - 1ms/step
# Epoch 205/300
# 1970/1970 - 3s - loss: 0.3534 - auc_1: 0.8681 - val_loss: 0.3514 - val_auc_1: 0.8694 - 3s/epoch - 1ms/step
# Epoch 206/300
# 1970/1970 - 3s - loss: 0.3534 - auc_1: 0.8681 - val_loss: 0.3514 - val_auc_1: 0.8694 - 3s/epoch - 1ms/step
# Epoch 207/300
# 1970/1970 - 3s - loss: 0.3534 - auc_1: 0.8681 - val_loss: 0.3514 - val_auc_1: 0.8694 - 3s/epoch - 1ms/step
# Epoch 208/300
# 1970/1970 - 3s - loss: 0.3534 - auc_1: 0.8681 - val_loss: 0.3513 - val_auc_1: 0.8695 - 3s/epoch - 1ms/step
# Epoch 209/300
# 1970/1970 - 3s - loss: 0.3533 - auc_1: 0.8681 - val_loss: 0.3513 - val_auc_1: 0.8695 - 3s/epoch - 1ms/step
# Epoch 210/300
# 1970/1970 - 3s - loss: 0.3533 - auc_1: 0.8682 - val_loss: 0.3513 - val_auc_1: 0.8695 - 3s/epoch - 1ms/step
# Epoch 211/300
# 1970/1970 - 3s - loss: 0.3533 - auc_1: 0.8682 - val_loss: 0.3513 - val_auc_1: 0.8696 - 3s/epoch - 1ms/step
# Epoch 212/300
# 1970/1970 - 3s - loss: 0.3533 - auc_1: 0.8682 - val_loss: 0.3512 - val_auc_1: 0.8696 - 3s/epoch - 1ms/step
# Epoch 213/300
# 1970/1970 - 3s - loss: 0.3532 - auc_1: 0.8682 - val_loss: 0.3512 - val_auc_1: 0.8696 - 3s/epoch - 1ms/step
# Epoch 214/300
# 1970/1970 - 3s - loss: 0.3532 - auc_1: 0.8682 - val_loss: 0.3512 - val_auc_1: 0.8696 - 3s/epoch - 1ms/step
# Epoch 215/300
# 1970/1970 - 3s - loss: 0.3532 - auc_1: 0.8682 - val_loss: 0.3512 - val_auc_1: 0.8696 - 3s/epoch - 1ms/step
# Epoch 216/300
# 1970/1970 - 3s - loss: 0.3532 - auc_1: 0.8683 - val_loss: 0.3511 - val_auc_1: 0.8697 - 3s/epoch - 1ms/step
# Epoch 217/300
# 1970/1970 - 3s - loss: 0.3532 - auc_1: 0.8683 - val_loss: 0.3511 - val_auc_1: 0.8697 - 3s/epoch - 1ms/step
# Epoch 218/300
# 1970/1970 - 3s - loss: 0.3531 - auc_1: 0.8683 - val_loss: 0.3511 - val_auc_1: 0.8697 - 3s/epoch - 1ms/step
# Epoch 219/300
# 1970/1970 - 3s - loss: 0.3531 - auc_1: 0.8683 - val_loss: 0.3511 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 220/300
# 1970/1970 - 3s - loss: 0.3531 - auc_1: 0.8683 - val_loss: 0.3510 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 221/300
# 1970/1970 - 3s - loss: 0.3531 - auc_1: 0.8683 - val_loss: 0.3510 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 222/300
# 1970/1970 - 3s - loss: 0.3530 - auc_1: 0.8684 - val_loss: 0.3510 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 223/300
# 1970/1970 - 3s - loss: 0.3530 - auc_1: 0.8684 - val_loss: 0.3510 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 224/300
# 1970/1970 - 3s - loss: 0.3530 - auc_1: 0.8684 - val_loss: 0.3510 - val_auc_1: 0.8698 - 3s/epoch - 1ms/step
# Epoch 225/300
# 1970/1970 - 3s - loss: 0.3530 - auc_1: 0.8684 - val_loss: 0.3509 - val_auc_1: 0.8699 - 3s/epoch - 1ms/step
# Epoch 226/300
# 1970/1970 - 3s - loss: 0.3529 - auc_1: 0.8684 - val_loss: 0.3509 - val_auc_1: 0.8699 - 3s/epoch - 1ms/step
# Epoch 227/300
# 1970/1970 - 3s - loss: 0.3529 - auc_1: 0.8684 - val_loss: 0.3509 - val_auc_1: 0.8699 - 3s/epoch - 1ms/step
# Epoch 228/300
# 1970/1970 - 3s - loss: 0.3529 - auc_1: 0.8685 - val_loss: 0.3508 - val_auc_1: 0.8699 - 3s/epoch - 1ms/step
# Epoch 229/300
# 1970/1970 - 3s - loss: 0.3529 - auc_1: 0.8685 - val_loss: 0.3508 - val_auc_1: 0.8700 - 3s/epoch - 1ms/step
# Epoch 230/300
# 1970/1970 - 3s - loss: 0.3529 - auc_1: 0.8685 - val_loss: 0.3508 - val_auc_1: 0.8700 - 3s/epoch - 1ms/step
# Epoch 231/300
# 1970/1970 - 3s - loss: 0.3528 - auc_1: 0.8685 - val_loss: 0.3508 - val_auc_1: 0.8700 - 3s/epoch - 1ms/step
# Epoch 232/300
# 1970/1970 - 3s - loss: 0.3528 - auc_1: 0.8685 - val_loss: 0.3508 - val_auc_1: 0.8700 - 3s/epoch - 1ms/step
# Epoch 233/300
# 1970/1970 - 3s - loss: 0.3528 - auc_1: 0.8686 - val_loss: 0.3507 - val_auc_1: 0.8700 - 3s/epoch - 1ms/step
# Epoch 234/300
# 1970/1970 - 3s - loss: 0.3528 - auc_1: 0.8686 - val_loss: 0.3507 - val_auc_1: 0.8701 - 3s/epoch - 1ms/step
# Epoch 235/300
# 1970/1970 - 3s - loss: 0.3527 - auc_1: 0.8686 - val_loss: 0.3507 - val_auc_1: 0.8701 - 3s/epoch - 1ms/step
# Epoch 236/300
# 1970/1970 - 3s - loss: 0.3527 - auc_1: 0.8686 - val_loss: 0.3507 - val_auc_1: 0.8701 - 3s/epoch - 1ms/step
# Epoch 237/300
# 1970/1970 - 3s - loss: 0.3527 - auc_1: 0.8686 - val_loss: 0.3506 - val_auc_1: 0.8702 - 3s/epoch - 1ms/step
# Epoch 238/300
# 1970/1970 - 3s - loss: 0.3527 - auc_1: 0.8687 - val_loss: 0.3506 - val_auc_1: 0.8701 - 3s/epoch - 1ms/step
# Epoch 239/300
# 1970/1970 - 3s - loss: 0.3526 - auc_1: 0.8687 - val_loss: 0.3506 - val_auc_1: 0.8702 - 3s/epoch - 1ms/step
# Epoch 240/300
# 1970/1970 - 3s - loss: 0.3526 - auc_1: 0.8687 - val_loss: 0.3506 - val_auc_1: 0.8702 - 3s/epoch - 1ms/step
# Epoch 241/300
# 1970/1970 - 3s - loss: 0.3526 - auc_1: 0.8687 - val_loss: 0.3505 - val_auc_1: 0.8702 - 3s/epoch - 1ms/step
# Epoch 242/300
# 1970/1970 - 3s - loss: 0.3526 - auc_1: 0.8687 - val_loss: 0.3505 - val_auc_1: 0.8702 - 3s/epoch - 1ms/step
# Epoch 243/300
# 1970/1970 - 3s - loss: 0.3526 - auc_1: 0.8687 - val_loss: 0.3505 - val_auc_1: 0.8703 - 3s/epoch - 1ms/step
# Epoch 244/300
# 1970/1970 - 3s - loss: 0.3525 - auc_1: 0.8688 - val_loss: 0.3505 - val_auc_1: 0.8703 - 3s/epoch - 1ms/step
# Epoch 245/300
# 1970/1970 - 3s - loss: 0.3525 - auc_1: 0.8688 - val_loss: 0.3504 - val_auc_1: 0.8703 - 3s/epoch - 1ms/step
# Epoch 246/300
# 1970/1970 - 3s - loss: 0.3525 - auc_1: 0.8688 - val_loss: 0.3504 - val_auc_1: 0.8703 - 3s/epoch - 1ms/step
# Epoch 247/300
# 1970/1970 - 3s - loss: 0.3525 - auc_1: 0.8688 - val_loss: 0.3504 - val_auc_1: 0.8703 - 3s/epoch - 1ms/step
# Epoch 248/300
# 1970/1970 - 3s - loss: 0.3524 - auc_1: 0.8688 - val_loss: 0.3504 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 249/300
# 1970/1970 - 3s - loss: 0.3524 - auc_1: 0.8688 - val_loss: 0.3504 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 250/300
# 1970/1970 - 3s - loss: 0.3524 - auc_1: 0.8688 - val_loss: 0.3503 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 251/300
# 1970/1970 - 3s - loss: 0.3524 - auc_1: 0.8689 - val_loss: 0.3503 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 252/300
# 1970/1970 - 3s - loss: 0.3524 - auc_1: 0.8689 - val_loss: 0.3503 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 253/300
# 1970/1970 - 3s - loss: 0.3523 - auc_1: 0.8689 - val_loss: 0.3503 - val_auc_1: 0.8705 - 3s/epoch - 1ms/step
# Epoch 254/300
# 1970/1970 - 3s - loss: 0.3523 - auc_1: 0.8689 - val_loss: 0.3503 - val_auc_1: 0.8704 - 3s/epoch - 1ms/step
# Epoch 255/300
# 1970/1970 - 3s - loss: 0.3523 - auc_1: 0.8690 - val_loss: 0.3502 - val_auc_1: 0.8705 - 3s/epoch - 1ms/step
# Epoch 256/300
# 1970/1970 - 3s - loss: 0.3523 - auc_1: 0.8690 - val_loss: 0.3502 - val_auc_1: 0.8705 - 3s/epoch - 1ms/step
# Epoch 257/300
# 1970/1970 - 3s - loss: 0.3522 - auc_1: 0.8690 - val_loss: 0.3502 - val_auc_1: 0.8705 - 3s/epoch - 1ms/step
# Epoch 258/300
# 1970/1970 - 3s - loss: 0.3522 - auc_1: 0.8690 - val_loss: 0.3501 - val_auc_1: 0.8705 - 3s/epoch - 1ms/step
# Epoch 259/300
# 1970/1970 - 3s - loss: 0.3522 - auc_1: 0.8690 - val_loss: 0.3501 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 260/300
# 1970/1970 - 3s - loss: 0.3522 - auc_1: 0.8690 - val_loss: 0.3501 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 261/300
# 1970/1970 - 3s - loss: 0.3522 - auc_1: 0.8690 - val_loss: 0.3501 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 262/300
# 1970/1970 - 3s - loss: 0.3521 - auc_1: 0.8691 - val_loss: 0.3500 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 263/300
# 1970/1970 - 3s - loss: 0.3521 - auc_1: 0.8691 - val_loss: 0.3500 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 264/300
# 1970/1970 - 3s - loss: 0.3521 - auc_1: 0.8691 - val_loss: 0.3500 - val_auc_1: 0.8706 - 3s/epoch - 1ms/step
# Epoch 265/300
# 1970/1970 - 3s - loss: 0.3521 - auc_1: 0.8691 - val_loss: 0.3500 - val_auc_1: 0.8707 - 3s/epoch - 1ms/step
# Epoch 266/300
# 1970/1970 - 3s - loss: 0.3520 - auc_1: 0.8691 - val_loss: 0.3500 - val_auc_1: 0.8707 - 3s/epoch - 1ms/step
# Epoch 267/300
# 1970/1970 - 3s - loss: 0.3520 - auc_1: 0.8692 - val_loss: 0.3499 - val_auc_1: 0.8707 - 3s/epoch - 1ms/step
# Epoch 268/300
# 1970/1970 - 3s - loss: 0.3520 - auc_1: 0.8692 - val_loss: 0.3499 - val_auc_1: 0.8707 - 3s/epoch - 1ms/step
# Epoch 269/300
# 1970/1970 - 3s - loss: 0.3520 - auc_1: 0.8692 - val_loss: 0.3499 - val_auc_1: 0.8707 - 3s/epoch - 1ms/step
# Epoch 270/300
# 1970/1970 - 3s - loss: 0.3520 - auc_1: 0.8692 - val_loss: 0.3499 - val_auc_1: 0.8708 - 3s/epoch - 1ms/step
# Epoch 271/300
# 1970/1970 - 3s - loss: 0.3519 - auc_1: 0.8693 - val_loss: 0.3498 - val_auc_1: 0.8708 - 3s/epoch - 1ms/step
# Epoch 272/300
# 1970/1970 - 3s - loss: 0.3519 - auc_1: 0.8693 - val_loss: 0.3498 - val_auc_1: 0.8708 - 3s/epoch - 1ms/step
# Epoch 273/300
# 1970/1970 - 3s - loss: 0.3519 - auc_1: 0.8693 - val_loss: 0.3498 - val_auc_1: 0.8708 - 3s/epoch - 1ms/step
# Epoch 274/300
# 1970/1970 - 3s - loss: 0.3519 - auc_1: 0.8693 - val_loss: 0.3498 - val_auc_1: 0.8708 - 3s/epoch - 1ms/step
# Epoch 275/300
# 1970/1970 - 3s - loss: 0.3518 - auc_1: 0.8693 - val_loss: 0.3497 - val_auc_1: 0.8709 - 3s/epoch - 1ms/step
# Epoch 276/300
# 1970/1970 - 3s - loss: 0.3518 - auc_1: 0.8693 - val_loss: 0.3497 - val_auc_1: 0.8709 - 3s/epoch - 1ms/step
# Epoch 277/300
# 1970/1970 - 3s - loss: 0.3518 - auc_1: 0.8693 - val_loss: 0.3497 - val_auc_1: 0.8709 - 3s/epoch - 1ms/step
# Epoch 278/300
# 1970/1970 - 3s - loss: 0.3518 - auc_1: 0.8694 - val_loss: 0.3497 - val_auc_1: 0.8709 - 3s/epoch - 1ms/step
# Epoch 279/300
# 1970/1970 - 3s - loss: 0.3518 - auc_1: 0.8694 - val_loss: 0.3497 - val_auc_1: 0.8709 - 3s/epoch - 1ms/step
# Epoch 280/300
# 1970/1970 - 3s - loss: 0.3517 - auc_1: 0.8694 - val_loss: 0.3496 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 281/300
# 1970/1970 - 3s - loss: 0.3517 - auc_1: 0.8694 - val_loss: 0.3496 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 282/300
# 1970/1970 - 3s - loss: 0.3517 - auc_1: 0.8694 - val_loss: 0.3496 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 283/300
# 1970/1970 - 3s - loss: 0.3517 - auc_1: 0.8695 - val_loss: 0.3496 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 284/300
# 1970/1970 - 3s - loss: 0.3517 - auc_1: 0.8695 - val_loss: 0.3495 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 285/300
# 1970/1970 - 3s - loss: 0.3516 - auc_1: 0.8695 - val_loss: 0.3495 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 286/300
# 1970/1970 - 3s - loss: 0.3516 - auc_1: 0.8695 - val_loss: 0.3495 - val_auc_1: 0.8710 - 3s/epoch - 1ms/step
# Epoch 287/300
# 1970/1970 - 3s - loss: 0.3516 - auc_1: 0.8695 - val_loss: 0.3495 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 288/300
# 1970/1970 - 3s - loss: 0.3516 - auc_1: 0.8696 - val_loss: 0.3495 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 289/300
# 1970/1970 - 3s - loss: 0.3515 - auc_1: 0.8696 - val_loss: 0.3494 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 290/300
# 1970/1970 - 3s - loss: 0.3515 - auc_1: 0.8696 - val_loss: 0.3494 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 291/300
# 1970/1970 - 3s - loss: 0.3515 - auc_1: 0.8696 - val_loss: 0.3494 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 292/300
# 1970/1970 - 3s - loss: 0.3515 - auc_1: 0.8696 - val_loss: 0.3494 - val_auc_1: 0.8711 - 3s/epoch - 1ms/step
# Epoch 293/300
# 1970/1970 - 3s - loss: 0.3515 - auc_1: 0.8696 - val_loss: 0.3493 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 294/300
# 1970/1970 - 3s - loss: 0.3514 - auc_1: 0.8697 - val_loss: 0.3493 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 295/300
# 1970/1970 - 3s - loss: 0.3514 - auc_1: 0.8697 - val_loss: 0.3493 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 296/300
# 1970/1970 - 3s - loss: 0.3514 - auc_1: 0.8697 - val_loss: 0.3493 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 297/300
# 1970/1970 - 3s - loss: 0.3514 - auc_1: 0.8697 - val_loss: 0.3493 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 298/300
# 1970/1970 - 3s - loss: 0.3513 - auc_1: 0.8697 - val_loss: 0.3492 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 299/300
# 1970/1970 - 3s - loss: 0.3513 - auc_1: 0.8697 - val_loss: 0.3492 - val_auc_1: 0.8712 - 3s/epoch - 1ms/step
# Epoch 300/300
# 1970/1970 - 3s - loss: 0.3513 - auc_1: 0.8697 - val_loss: 0.3492 - val_auc_1: 0.8713 - 3s/epoch - 1ms/step

# %%
fig = plt.figure(figsize=(12, 6), dpi=100)
plt.plot(history1.history["val_loss"], label="validation loss")
plt.plot(history1.history["loss"], label="training loss")
plt.xlabel("Epoch", weight="bold", fontsize=16)
plt.ylabel("Loss", weight="bold", fontsize=16)
plt.legend()

# %% [markdown]
# ## Modelo 2
# Ahora probamos con el dataset completo, con una capa de entrada de 112 neuronas y una capa oculta de 56 neuronas, ambas con función de activación ReLU. Utilizaremos regularizacion L1 en la capa oculta, y el optimizador Adam.

# %%
X_train2 = preprocessing_redes_1(X_train)
X_train2, X_validation2, y_train2, y_validation2 = train_test_split(X_train2, y_train, random_state=117, test_size=0.3, stratify=y_train)

model2 = Sequential()
model2.add(Dense(112, input_dim=112, activation='relu'))
model2.add(Dense(56, input_dim =112, activation='relu', kernel_regularizer=tensorflow.keras.regularizers.l1(0.001)))
model2.add(Dense(1, activation='sigmoid'))
model2.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=[tensorflow.keras.metrics.AUC()])

# %%
history2 = model2.fit(X_train2.values, y_train2, epochs=100, verbose=2, validation_data=(X_validation2.values, y_validation2))
# Out:
# Epoch 1/100
# 1970/1970 - 4s - loss: 0.7406 - auc_2: 0.8371 - val_loss: 0.5514 - val_auc_2: 0.8662 - 4s/epoch - 2ms/step
# Epoch 2/100
# 1970/1970 - 3s - loss: 0.4996 - auc_2: 0.8698 - val_loss: 0.4636 - val_auc_2: 0.8723 - 3s/epoch - 2ms/step
# Epoch 3/100
# 1970/1970 - 3s - loss: 0.4440 - auc_2: 0.8735 - val_loss: 0.4276 - val_auc_2: 0.8739 - 3s/epoch - 2ms/step
# Epoch 4/100
# 1970/1970 - 3s - loss: 0.4170 - auc_2: 0.8752 - val_loss: 0.4086 - val_auc_2: 0.8748 - 3s/epoch - 2ms/step
# Epoch 5/100
# 1970/1970 - 3s - loss: 0.4011 - auc_2: 0.8760 - val_loss: 0.3944 - val_auc_2: 0.8764 - 3s/epoch - 2ms/step
# Epoch 6/100
# 1970/1970 - 3s - loss: 0.3896 - auc_2: 0.8772 - val_loss: 0.3851 - val_auc_2: 0.8767 - 3s/epoch - 2ms/step
# Epoch 7/100
# 1970/1970 - 3s - loss: 0.3814 - auc_2: 0.8780 - val_loss: 0.3784 - val_auc_2: 0.8777 - 3s/epoch - 2ms/step
# Epoch 8/100
# 1970/1970 - 3s - loss: 0.3747 - auc_2: 0.8791 - val_loss: 0.3728 - val_auc_2: 0.8784 - 3s/epoch - 2ms/step
# Epoch 9/100
# 1970/1970 - 3s - loss: 0.3702 - auc_2: 0.8796 - val_loss: 0.3695 - val_auc_2: 0.8791 - 3s/epoch - 2ms/step
# Epoch 10/100
# 1970/1970 - 3s - loss: 0.3662 - auc_2: 0.8806 - val_loss: 0.3647 - val_auc_2: 0.8800 - 3s/epoch - 2ms/step
# Epoch 11/100
# 1970/1970 - 3s - loss: 0.3628 - auc_2: 0.8816 - val_loss: 0.3621 - val_auc_2: 0.8808 - 3s/epoch - 2ms/step
# Epoch 12/100
# 1970/1970 - 3s - loss: 0.3598 - auc_2: 0.8826 - val_loss: 0.3597 - val_auc_2: 0.8815 - 3s/epoch - 2ms/step
# Epoch 13/100
# 1970/1970 - 3s - loss: 0.3575 - auc_2: 0.8833 - val_loss: 0.3587 - val_auc_2: 0.8818 - 3s/epoch - 2ms/step
# Epoch 14/100
# 1970/1970 - 3s - loss: 0.3553 - auc_2: 0.8842 - val_loss: 0.3569 - val_auc_2: 0.8824 - 3s/epoch - 2ms/step
# Epoch 15/100
# 1970/1970 - 3s - loss: 0.3533 - auc_2: 0.8849 - val_loss: 0.3538 - val_auc_2: 0.8832 - 3s/epoch - 2ms/step
# Epoch 16/100
# 1970/1970 - 3s - loss: 0.3513 - auc_2: 0.8859 - val_loss: 0.3522 - val_auc_2: 0.8840 - 3s/epoch - 2ms/step
# Epoch 17/100
# 1970/1970 - 3s - loss: 0.3498 - auc_2: 0.8865 - val_loss: 0.3524 - val_auc_2: 0.8843 - 3s/epoch - 2ms/step
# Epoch 18/100
# 1970/1970 - 3s - loss: 0.3484 - auc_2: 0.8870 - val_loss: 0.3498 - val_auc_2: 0.8849 - 3s/epoch - 2ms/step
# Epoch 19/100
# 1970/1970 - 3s - loss: 0.3469 - auc_2: 0.8877 - val_loss: 0.3487 - val_auc_2: 0.8852 - 3s/epoch - 2ms/step
# Epoch 20/100
# 1970/1970 - 3s - loss: 0.3457 - auc_2: 0.8884 - val_loss: 0.3473 - val_auc_2: 0.8858 - 3s/epoch - 2ms/step
# Epoch 21/100
# 1970/1970 - 3s - loss: 0.3443 - auc_2: 0.8892 - val_loss: 0.3466 - val_auc_2: 0.8859 - 3s/epoch - 2ms/step
# Epoch 22/100
# 1970/1970 - 3s - loss: 0.3430 - auc_2: 0.8898 - val_loss: 0.3453 - val_auc_2: 0.8867 - 3s/epoch - 2ms/step
# Epoch 23/100
# 1970/1970 - 3s - loss: 0.3420 - auc_2: 0.8904 - val_loss: 0.3448 - val_auc_2: 0.8870 - 3s/epoch - 2ms/step
# Epoch 24/100
# 1970/1970 - 3s - loss: 0.3410 - auc_2: 0.8910 - val_loss: 0.3439 - val_auc_2: 0.8874 - 3s/epoch - 2ms/step
# Epoch 25/100
# 1970/1970 - 3s - loss: 0.3400 - auc_2: 0.8915 - val_loss: 0.3447 - val_auc_2: 0.8877 - 3s/epoch - 2ms/step
# Epoch 26/100
# 1970/1970 - 3s - loss: 0.3390 - auc_2: 0.8921 - val_loss: 0.3426 - val_auc_2: 0.8882 - 3s/epoch - 2ms/step
# Epoch 27/100
# 1970/1970 - 3s - loss: 0.3382 - auc_2: 0.8926 - val_loss: 0.3431 - val_auc_2: 0.8886 - 3s/epoch - 2ms/step
# Epoch 28/100
# 1970/1970 - 3s - loss: 0.3373 - auc_2: 0.8932 - val_loss: 0.3416 - val_auc_2: 0.8889 - 3s/epoch - 2ms/step
# Epoch 29/100
# 1970/1970 - 3s - loss: 0.3365 - auc_2: 0.8936 - val_loss: 0.3409 - val_auc_2: 0.8891 - 3s/epoch - 2ms/step
# Epoch 30/100
# 1970/1970 - 3s - loss: 0.3354 - auc_2: 0.8943 - val_loss: 0.3408 - val_auc_2: 0.8896 - 3s/epoch - 2ms/step
# Epoch 31/100
# 1970/1970 - 3s - loss: 0.3346 - auc_2: 0.8949 - val_loss: 0.3401 - val_auc_2: 0.8902 - 3s/epoch - 2ms/step
# Epoch 32/100
# 1970/1970 - 3s - loss: 0.3338 - auc_2: 0.8954 - val_loss: 0.3390 - val_auc_2: 0.8904 - 3s/epoch - 2ms/step
# Epoch 33/100
# 1970/1970 - 3s - loss: 0.3330 - auc_2: 0.8960 - val_loss: 0.3384 - val_auc_2: 0.8905 - 3s/epoch - 2ms/step
# Epoch 34/100
# 1970/1970 - 3s - loss: 0.3321 - auc_2: 0.8965 - val_loss: 0.3382 - val_auc_2: 0.8906 - 3s/epoch - 2ms/step
# Epoch 35/100
# 1970/1970 - 3s - loss: 0.3312 - auc_2: 0.8971 - val_loss: 0.3381 - val_auc_2: 0.8909 - 3s/epoch - 2ms/step
# Epoch 36/100
# 1970/1970 - 3s - loss: 0.3307 - auc_2: 0.8975 - val_loss: 0.3367 - val_auc_2: 0.8915 - 3s/epoch - 2ms/step
# Epoch 37/100
# 1970/1970 - 3s - loss: 0.3300 - auc_2: 0.8977 - val_loss: 0.3366 - val_auc_2: 0.8916 - 3s/epoch - 2ms/step
# Epoch 38/100
# 1970/1970 - 3s - loss: 0.3292 - auc_2: 0.8984 - val_loss: 0.3366 - val_auc_2: 0.8916 - 3s/epoch - 2ms/step
# Epoch 39/100
# 1970/1970 - 3s - loss: 0.3285 - auc_2: 0.8989 - val_loss: 0.3369 - val_auc_2: 0.8921 - 3s/epoch - 2ms/step
# Epoch 40/100
# 1970/1970 - 3s - loss: 0.3277 - auc_2: 0.8993 - val_loss: 0.3371 - val_auc_2: 0.8920 - 3s/epoch - 2ms/step
# Epoch 41/100
# 1970/1970 - 3s - loss: 0.3270 - auc_2: 0.8999 - val_loss: 0.3351 - val_auc_2: 0.8925 - 3s/epoch - 2ms/step
# Epoch 42/100
# 1970/1970 - 3s - loss: 0.3264 - auc_2: 0.9002 - val_loss: 0.3351 - val_auc_2: 0.8924 - 3s/epoch - 2ms/step
# Epoch 43/100
# 1970/1970 - 3s - loss: 0.3258 - auc_2: 0.9005 - val_loss: 0.3341 - val_auc_2: 0.8931 - 3s/epoch - 2ms/step
# Epoch 44/100
# 1970/1970 - 3s - loss: 0.3251 - auc_2: 0.9009 - val_loss: 0.3343 - val_auc_2: 0.8930 - 3s/epoch - 2ms/step
# Epoch 45/100
# 1970/1970 - 3s - loss: 0.3245 - auc_2: 0.9013 - val_loss: 0.3339 - val_auc_2: 0.8933 - 3s/epoch - 2ms/step
# Epoch 46/100
# 1970/1970 - 3s - loss: 0.3240 - auc_2: 0.9018 - val_loss: 0.3346 - val_auc_2: 0.8934 - 3s/epoch - 2ms/step
# Epoch 47/100
# 1970/1970 - 3s - loss: 0.3234 - auc_2: 0.9021 - val_loss: 0.3328 - val_auc_2: 0.8938 - 3s/epoch - 2ms/step
# Epoch 48/100
# 1970/1970 - 3s - loss: 0.3226 - auc_2: 0.9027 - val_loss: 0.3328 - val_auc_2: 0.8939 - 3s/epoch - 2ms/step
# Epoch 49/100
# 1970/1970 - 3s - loss: 0.3223 - auc_2: 0.9029 - val_loss: 0.3328 - val_auc_2: 0.8941 - 3s/epoch - 2ms/step
# Epoch 50/100
# 1970/1970 - 3s - loss: 0.3216 - auc_2: 0.9032 - val_loss: 0.3344 - val_auc_2: 0.8942 - 3s/epoch - 2ms/step
# Epoch 51/100
# 1970/1970 - 3s - loss: 0.3210 - auc_2: 0.9037 - val_loss: 0.3325 - val_auc_2: 0.8946 - 3s/epoch - 2ms/step
# Epoch 52/100
# 1970/1970 - 3s - loss: 0.3206 - auc_2: 0.9040 - val_loss: 0.3314 - val_auc_2: 0.8947 - 3s/epoch - 2ms/step
# Epoch 53/100
# 1970/1970 - 3s - loss: 0.3201 - auc_2: 0.9043 - val_loss: 0.3311 - val_auc_2: 0.8948 - 3s/epoch - 2ms/step
# Epoch 54/100
# 1970/1970 - 3s - loss: 0.3194 - auc_2: 0.9047 - val_loss: 0.3321 - val_auc_2: 0.8947 - 3s/epoch - 2ms/step
# Epoch 55/100
# 1970/1970 - 3s - loss: 0.3191 - auc_2: 0.9049 - val_loss: 0.3314 - val_auc_2: 0.8946 - 3s/epoch - 2ms/step
# Epoch 56/100
# 1970/1970 - 3s - loss: 0.3185 - auc_2: 0.9053 - val_loss: 0.3316 - val_auc_2: 0.8950 - 3s/epoch - 2ms/step
# Epoch 57/100
# 1970/1970 - 3s - loss: 0.3181 - auc_2: 0.9055 - val_loss: 0.3316 - val_auc_2: 0.8948 - 3s/epoch - 2ms/step
# Epoch 58/100
# 1970/1970 - 3s - loss: 0.3176 - auc_2: 0.9058 - val_loss: 0.3309 - val_auc_2: 0.8952 - 3s/epoch - 2ms/step
# Epoch 59/100
# 1970/1970 - 3s - loss: 0.3171 - auc_2: 0.9062 - val_loss: 0.3304 - val_auc_2: 0.8951 - 3s/epoch - 2ms/step
# Epoch 60/100
# 1970/1970 - 3s - loss: 0.3168 - auc_2: 0.9064 - val_loss: 0.3316 - val_auc_2: 0.8950 - 3s/epoch - 2ms/step
# Epoch 61/100
# 1970/1970 - 3s - loss: 0.3161 - auc_2: 0.9069 - val_loss: 0.3302 - val_auc_2: 0.8953 - 3s/epoch - 2ms/step
# Epoch 62/100
# 1970/1970 - 3s - loss: 0.3158 - auc_2: 0.9069 - val_loss: 0.3301 - val_auc_2: 0.8954 - 3s/epoch - 2ms/step
# Epoch 63/100
# 1970/1970 - 3s - loss: 0.3153 - auc_2: 0.9073 - val_loss: 0.3301 - val_auc_2: 0.8954 - 3s/epoch - 2ms/step
# Epoch 64/100
# 1970/1970 - 3s - loss: 0.3150 - auc_2: 0.9075 - val_loss: 0.3296 - val_auc_2: 0.8956 - 3s/epoch - 2ms/step
# Epoch 65/100
# 1970/1970 - 3s - loss: 0.3147 - auc_2: 0.9078 - val_loss: 0.3292 - val_auc_2: 0.8959 - 3s/epoch - 2ms/step
# Epoch 66/100
# 1970/1970 - 3s - loss: 0.3141 - auc_2: 0.9082 - val_loss: 0.3304 - val_auc_2: 0.8958 - 3s/epoch - 2ms/step
# Epoch 67/100
# 1970/1970 - 3s - loss: 0.3136 - auc_2: 0.9085 - val_loss: 0.3294 - val_auc_2: 0.8959 - 3s/epoch - 2ms/step
# Epoch 68/100
# 1970/1970 - 3s - loss: 0.3131 - auc_2: 0.9088 - val_loss: 0.3287 - val_auc_2: 0.8960 - 3s/epoch - 2ms/step
# Epoch 69/100
# 1970/1970 - 3s - loss: 0.3128 - auc_2: 0.9090 - val_loss: 0.3292 - val_auc_2: 0.8960 - 3s/epoch - 2ms/step
# Epoch 70/100
# 1970/1970 - 3s - loss: 0.3125 - auc_2: 0.9092 - val_loss: 0.3288 - val_auc_2: 0.8960 - 3s/epoch - 2ms/step
# Epoch 71/100
# 1970/1970 - 3s - loss: 0.3119 - auc_2: 0.9096 - val_loss: 0.3285 - val_auc_2: 0.8963 - 3s/epoch - 2ms/step
# Epoch 72/100
# 1970/1970 - 3s - loss: 0.3116 - auc_2: 0.9099 - val_loss: 0.3287 - val_auc_2: 0.8964 - 3s/epoch - 2ms/step
# Epoch 73/100
# 1970/1970 - 3s - loss: 0.3110 - auc_2: 0.9102 - val_loss: 0.3293 - val_auc_2: 0.8959 - 3s/epoch - 2ms/step
# Epoch 74/100
# 1970/1970 - 3s - loss: 0.3106 - auc_2: 0.9106 - val_loss: 0.3295 - val_auc_2: 0.8962 - 3s/epoch - 2ms/step
# Epoch 75/100
# 1970/1970 - 3s - loss: 0.3103 - auc_2: 0.9107 - val_loss: 0.3294 - val_auc_2: 0.8961 - 3s/epoch - 2ms/step
# Epoch 76/100
# 1970/1970 - 3s - loss: 0.3100 - auc_2: 0.9110 - val_loss: 0.3290 - val_auc_2: 0.8963 - 3s/epoch - 2ms/step
# Epoch 77/100
# 1970/1970 - 3s - loss: 0.3096 - auc_2: 0.9111 - val_loss: 0.3289 - val_auc_2: 0.8963 - 3s/epoch - 2ms/step
# Epoch 78/100
# 1970/1970 - 3s - loss: 0.3091 - auc_2: 0.9115 - val_loss: 0.3294 - val_auc_2: 0.8964 - 3s/epoch - 2ms/step
# Epoch 79/100
# 1970/1970 - 3s - loss: 0.3088 - auc_2: 0.9117 - val_loss: 0.3315 - val_auc_2: 0.8962 - 3s/epoch - 2ms/step
# Epoch 80/100
# 1970/1970 - 3s - loss: 0.3084 - auc_2: 0.9120 - val_loss: 0.3288 - val_auc_2: 0.8964 - 3s/epoch - 2ms/step
# Epoch 81/100
# 1970/1970 - 3s - loss: 0.3081 - auc_2: 0.9122 - val_loss: 0.3292 - val_auc_2: 0.8961 - 3s/epoch - 2ms/step
# Epoch 82/100
# 1970/1970 - 3s - loss: 0.3078 - auc_2: 0.9124 - val_loss: 0.3288 - val_auc_2: 0.8964 - 3s/epoch - 2ms/step
# Epoch 83/100
# 1970/1970 - 3s - loss: 0.3072 - auc_2: 0.9128 - val_loss: 0.3284 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 84/100
# 1970/1970 - 3s - loss: 0.3069 - auc_2: 0.9130 - val_loss: 0.3289 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 85/100
# 1970/1970 - 3s - loss: 0.3067 - auc_2: 0.9133 - val_loss: 0.3289 - val_auc_2: 0.8964 - 3s/epoch - 2ms/step
# Epoch 86/100
# 1970/1970 - 3s - loss: 0.3064 - auc_2: 0.9135 - val_loss: 0.3284 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 87/100
# 1970/1970 - 3s - loss: 0.3060 - auc_2: 0.9137 - val_loss: 0.3293 - val_auc_2: 0.8968 - 3s/epoch - 2ms/step
# Epoch 88/100
# 1970/1970 - 3s - loss: 0.3056 - auc_2: 0.9139 - val_loss: 0.3283 - val_auc_2: 0.8968 - 3s/epoch - 2ms/step
# Epoch 89/100
# 1970/1970 - 3s - loss: 0.3052 - auc_2: 0.9142 - val_loss: 0.3285 - val_auc_2: 0.8970 - 3s/epoch - 2ms/step
# Epoch 90/100
# 1970/1970 - 3s - loss: 0.3049 - auc_2: 0.9145 - val_loss: 0.3286 - val_auc_2: 0.8966 - 3s/epoch - 2ms/step
# Epoch 91/100
# 1970/1970 - 3s - loss: 0.3045 - auc_2: 0.9147 - val_loss: 0.3294 - val_auc_2: 0.8966 - 3s/epoch - 2ms/step
# Epoch 92/100
# 1970/1970 - 3s - loss: 0.3042 - auc_2: 0.9149 - val_loss: 0.3287 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 93/100
# 1970/1970 - 3s - loss: 0.3039 - auc_2: 0.9152 - val_loss: 0.3295 - val_auc_2: 0.8966 - 3s/epoch - 2ms/step
# Epoch 94/100
# 1970/1970 - 3s - loss: 0.3035 - auc_2: 0.9155 - val_loss: 0.3292 - val_auc_2: 0.8962 - 3s/epoch - 2ms/step
# Epoch 95/100
# 1970/1970 - 3s - loss: 0.3033 - auc_2: 0.9156 - val_loss: 0.3287 - val_auc_2: 0.8969 - 3s/epoch - 2ms/step
# Epoch 96/100
# 1970/1970 - 3s - loss: 0.3028 - auc_2: 0.9160 - val_loss: 0.3302 - val_auc_2: 0.8961 - 3s/epoch - 2ms/step
# Epoch 97/100
# 1970/1970 - 3s - loss: 0.3025 - auc_2: 0.9162 - val_loss: 0.3291 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 98/100
# 1970/1970 - 3s - loss: 0.3020 - auc_2: 0.9166 - val_loss: 0.3294 - val_auc_2: 0.8962 - 3s/epoch - 2ms/step
# Epoch 99/100
# 1970/1970 - 3s - loss: 0.3018 - auc_2: 0.9167 - val_loss: 0.3289 - val_auc_2: 0.8967 - 3s/epoch - 2ms/step
# Epoch 100/100
# 1970/1970 - 3s - loss: 0.3015 - auc_2: 0.9170 - val_loss: 0.3291 - val_auc_2: 0.8968 - 3s/epoch - 2ms/step

# %%
fig = plt.figure(figsize=(12, 6), dpi=100)
plt.plot(history2.history["val_loss"], label="validation loss")
plt.plot(history2.history["loss"], label="training loss")
plt.xlabel("Epoch", weight="bold", fontsize=16)
plt.ylabel("Loss", weight="bold", fontsize=16)
plt.legend()

# %% [markdown]
# ## Modelo 3
#
# Por ultimo, probamos agregando regularizacion L1 en la capa de entrada

# %%
model3 = Sequential()
model3.add(Dense(112, input_dim=112, activation='relu', kernel_regularizer=tensorflow.keras.regularizers.l1(0.001)))
model3.add(Dense(56, activation='relu', kernel_regularizer=tensorflow.keras.regularizers.l1(0.001)))
model3.add(Dense(1, activation='sigmoid'))

model3.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=[tensorflow.keras.metrics.AUC()])

# %%
history3 = model3.fit(X_train2.values, y_train2, epochs=100, verbose=2, validation_data=(X_validation2.values, y_validation2))
# Out:
# Epoch 1/100
# 1970/1970 - 4s - loss: 1.1846 - auc_3: 0.8315 - val_loss: 0.6663 - val_auc_3: 0.8606 - 4s/epoch - 2ms/step
# Epoch 2/100
# 1970/1970 - 3s - loss: 0.5672 - auc_3: 0.8626 - val_loss: 0.5063 - val_auc_3: 0.8644 - 3s/epoch - 2ms/step
# Epoch 3/100
# 1970/1970 - 3s - loss: 0.4807 - auc_3: 0.8639 - val_loss: 0.4589 - val_auc_3: 0.8658 - 3s/epoch - 2ms/step
# Epoch 4/100
# 1970/1970 - 3s - loss: 0.4464 - auc_3: 0.8640 - val_loss: 0.4334 - val_auc_3: 0.8655 - 3s/epoch - 2ms/step
# Epoch 5/100
# 1970/1970 - 3s - loss: 0.4274 - auc_3: 0.8642 - val_loss: 0.4204 - val_auc_3: 0.8660 - 3s/epoch - 2ms/step
# Epoch 6/100
# 1970/1970 - 3s - loss: 0.4154 - auc_3: 0.8646 - val_loss: 0.4095 - val_auc_3: 0.8660 - 3s/epoch - 2ms/step
# Epoch 7/100
# 1970/1970 - 3s - loss: 0.4071 - auc_3: 0.8648 - val_loss: 0.4019 - val_auc_3: 0.8662 - 3s/epoch - 2ms/step
# Epoch 8/100
# 1970/1970 - 3s - loss: 0.4007 - auc_3: 0.8653 - val_loss: 0.3968 - val_auc_3: 0.8666 - 3s/epoch - 2ms/step
# Epoch 9/100
# 1970/1970 - 3s - loss: 0.3963 - auc_3: 0.8655 - val_loss: 0.3931 - val_auc_3: 0.8670 - 3s/epoch - 2ms/step
# Epoch 10/100
# 1970/1970 - 3s - loss: 0.3931 - auc_3: 0.8659 - val_loss: 0.3944 - val_auc_3: 0.8670 - 3s/epoch - 2ms/step
# Epoch 11/100
# 1970/1970 - 3s - loss: 0.3907 - auc_3: 0.8660 - val_loss: 0.3878 - val_auc_3: 0.8672 - 3s/epoch - 2ms/step
# Epoch 12/100
# 1970/1970 - 3s - loss: 0.3884 - auc_3: 0.8663 - val_loss: 0.3856 - val_auc_3: 0.8675 - 3s/epoch - 2ms/step
# Epoch 13/100
# 1970/1970 - 3s - loss: 0.3866 - auc_3: 0.8667 - val_loss: 0.3844 - val_auc_3: 0.8680 - 3s/epoch - 2ms/step
# Epoch 14/100
# 1970/1970 - 3s - loss: 0.3849 - auc_3: 0.8671 - val_loss: 0.3824 - val_auc_3: 0.8684 - 3s/epoch - 2ms/step
# Epoch 15/100
# 1970/1970 - 3s - loss: 0.3835 - auc_3: 0.8674 - val_loss: 0.3810 - val_auc_3: 0.8687 - 3s/epoch - 2ms/step
# Epoch 16/100
# 1970/1970 - 4s - loss: 0.3820 - auc_3: 0.8677 - val_loss: 0.3804 - val_auc_3: 0.8690 - 4s/epoch - 2ms/step
# Epoch 17/100
# 1970/1970 - 5s - loss: 0.3808 - auc_3: 0.8680 - val_loss: 0.3791 - val_auc_3: 0.8694 - 5s/epoch - 3ms/step
# Epoch 18/100
# 1970/1970 - 4s - loss: 0.3798 - auc_3: 0.8682 - val_loss: 0.3776 - val_auc_3: 0.8697 - 4s/epoch - 2ms/step
# Epoch 19/100
# 1970/1970 - 4s - loss: 0.3786 - auc_3: 0.8687 - val_loss: 0.3762 - val_auc_3: 0.8700 - 4s/epoch - 2ms/step
# Epoch 20/100
# 1970/1970 - 3s - loss: 0.3774 - auc_3: 0.8692 - val_loss: 0.3751 - val_auc_3: 0.8705 - 3s/epoch - 2ms/step
# Epoch 21/100
# 1970/1970 - 3s - loss: 0.3764 - auc_3: 0.8695 - val_loss: 0.3758 - val_auc_3: 0.8708 - 3s/epoch - 2ms/step
# Epoch 22/100
# 1970/1970 - 3s - loss: 0.3755 - auc_3: 0.8699 - val_loss: 0.3742 - val_auc_3: 0.8711 - 3s/epoch - 2ms/step
# Epoch 23/100
# 1970/1970 - 3s - loss: 0.3745 - auc_3: 0.8702 - val_loss: 0.3723 - val_auc_3: 0.8715 - 3s/epoch - 2ms/step
# Epoch 24/100
# 1970/1970 - 3s - loss: 0.3734 - auc_3: 0.8706 - val_loss: 0.3723 - val_auc_3: 0.8717 - 3s/epoch - 2ms/step
# Epoch 25/100
# 1970/1970 - 3s - loss: 0.3725 - auc_3: 0.8709 - val_loss: 0.3706 - val_auc_3: 0.8723 - 3s/epoch - 2ms/step
# Epoch 26/100
# 1970/1970 - 3s - loss: 0.3717 - auc_3: 0.8711 - val_loss: 0.3704 - val_auc_3: 0.8724 - 3s/epoch - 2ms/step
# Epoch 27/100
# 1970/1970 - 3s - loss: 0.3709 - auc_3: 0.8715 - val_loss: 0.3690 - val_auc_3: 0.8727 - 3s/epoch - 2ms/step
# Epoch 28/100
# 1970/1970 - 4s - loss: 0.3701 - auc_3: 0.8718 - val_loss: 0.3681 - val_auc_3: 0.8732 - 4s/epoch - 2ms/step
# Epoch 29/100
# 1970/1970 - 4s - loss: 0.3693 - auc_3: 0.8722 - val_loss: 0.3679 - val_auc_3: 0.8733 - 4s/epoch - 2ms/step
# Epoch 30/100
# 1970/1970 - 3s - loss: 0.3689 - auc_3: 0.8724 - val_loss: 0.3671 - val_auc_3: 0.8737 - 3s/epoch - 2ms/step
# Epoch 31/100
# 1970/1970 - 3s - loss: 0.3682 - auc_3: 0.8728 - val_loss: 0.3667 - val_auc_3: 0.8738 - 3s/epoch - 2ms/step
# Epoch 32/100
# 1970/1970 - 3s - loss: 0.3678 - auc_3: 0.8729 - val_loss: 0.3661 - val_auc_3: 0.8741 - 3s/epoch - 2ms/step
# Epoch 33/100
# 1970/1970 - 3s - loss: 0.3673 - auc_3: 0.8732 - val_loss: 0.3657 - val_auc_3: 0.8742 - 3s/epoch - 2ms/step
# Epoch 34/100
# 1970/1970 - 3s - loss: 0.3669 - auc_3: 0.8733 - val_loss: 0.3656 - val_auc_3: 0.8746 - 3s/epoch - 2ms/step
# Epoch 35/100
# 1970/1970 - 3s - loss: 0.3664 - auc_3: 0.8737 - val_loss: 0.3652 - val_auc_3: 0.8745 - 3s/epoch - 2ms/step
# Epoch 36/100
# 1970/1970 - 3s - loss: 0.3660 - auc_3: 0.8738 - val_loss: 0.3645 - val_auc_3: 0.8748 - 3s/epoch - 2ms/step
# Epoch 37/100
# 1970/1970 - 3s - loss: 0.3657 - auc_3: 0.8739 - val_loss: 0.3648 - val_auc_3: 0.8749 - 3s/epoch - 2ms/step
# Epoch 38/100
# 1970/1970 - 3s - loss: 0.3651 - auc_3: 0.8742 - val_loss: 0.3638 - val_auc_3: 0.8751 - 3s/epoch - 2ms/step
# Epoch 39/100
# 1970/1970 - 3s - loss: 0.3648 - auc_3: 0.8744 - val_loss: 0.3642 - val_auc_3: 0.8749 - 3s/epoch - 2ms/step
# Epoch 40/100
# 1970/1970 - 3s - loss: 0.3645 - auc_3: 0.8744 - val_loss: 0.3631 - val_auc_3: 0.8752 - 3s/epoch - 2ms/step
# Epoch 41/100
# 1970/1970 - 3s - loss: 0.3641 - auc_3: 0.8746 - val_loss: 0.3641 - val_auc_3: 0.8751 - 3s/epoch - 2ms/step
# Epoch 42/100
# 1970/1970 - 3s - loss: 0.3640 - auc_3: 0.8745 - val_loss: 0.3625 - val_auc_3: 0.8754 - 3s/epoch - 2ms/step
# Epoch 43/100
# 1970/1970 - 3s - loss: 0.3635 - auc_3: 0.8746 - val_loss: 0.3621 - val_auc_3: 0.8755 - 3s/epoch - 2ms/step
# Epoch 44/100
# 1970/1970 - 3s - loss: 0.3632 - auc_3: 0.8747 - val_loss: 0.3619 - val_auc_3: 0.8755 - 3s/epoch - 2ms/step
# Epoch 45/100
# 1970/1970 - 3s - loss: 0.3630 - auc_3: 0.8748 - val_loss: 0.3619 - val_auc_3: 0.8755 - 3s/epoch - 2ms/step
# Epoch 46/100
# 1970/1970 - 3s - loss: 0.3627 - auc_3: 0.8749 - val_loss: 0.3617 - val_auc_3: 0.8756 - 3s/epoch - 2ms/step
# Epoch 47/100
# 1970/1970 - 3s - loss: 0.3625 - auc_3: 0.8750 - val_loss: 0.3615 - val_auc_3: 0.8757 - 3s/epoch - 2ms/step
# Epoch 48/100
# 1970/1970 - 3s - loss: 0.3623 - auc_3: 0.8751 - val_loss: 0.3612 - val_auc_3: 0.8758 - 3s/epoch - 2ms/step
# Epoch 49/100
# 1970/1970 - 3s - loss: 0.3621 - auc_3: 0.8751 - val_loss: 0.3612 - val_auc_3: 0.8757 - 3s/epoch - 2ms/step
# Epoch 50/100
# 1970/1970 - 3s - loss: 0.3619 - auc_3: 0.8751 - val_loss: 0.3608 - val_auc_3: 0.8758 - 3s/epoch - 2ms/step
# Epoch 51/100
# 1970/1970 - 3s - loss: 0.3616 - auc_3: 0.8753 - val_loss: 0.3604 - val_auc_3: 0.8759 - 3s/epoch - 2ms/step
# Epoch 52/100
# 1970/1970 - 3s - loss: 0.3615 - auc_3: 0.8752 - val_loss: 0.3601 - val_auc_3: 0.8759 - 3s/epoch - 2ms/step
# Epoch 53/100
# 1970/1970 - 3s - loss: 0.3614 - auc_3: 0.8752 - val_loss: 0.3598 - val_auc_3: 0.8760 - 3s/epoch - 2ms/step
# Epoch 54/100
# 1970/1970 - 3s - loss: 0.3611 - auc_3: 0.8753 - val_loss: 0.3596 - val_auc_3: 0.8761 - 3s/epoch - 2ms/step
# Epoch 55/100
# 1970/1970 - 3s - loss: 0.3608 - auc_3: 0.8754 - val_loss: 0.3594 - val_auc_3: 0.8762 - 3s/epoch - 2ms/step
# Epoch 56/100
# 1970/1970 - 3s - loss: 0.3607 - auc_3: 0.8755 - val_loss: 0.3596 - val_auc_3: 0.8761 - 3s/epoch - 2ms/step
# Epoch 57/100
# 1970/1970 - 3s - loss: 0.3607 - auc_3: 0.8754 - val_loss: 0.3594 - val_auc_3: 0.8761 - 3s/epoch - 2ms/step
# Epoch 58/100
# 1970/1970 - 3s - loss: 0.3605 - auc_3: 0.8754 - val_loss: 0.3592 - val_auc_3: 0.8762 - 3s/epoch - 2ms/step
# Epoch 59/100
# 1970/1970 - 3s - loss: 0.3603 - auc_3: 0.8755 - val_loss: 0.3592 - val_auc_3: 0.8761 - 3s/epoch - 2ms/step
# Epoch 60/100
# 1970/1970 - 3s - loss: 0.3603 - auc_3: 0.8754 - val_loss: 0.3589 - val_auc_3: 0.8762 - 3s/epoch - 2ms/step
# Epoch 61/100
# 1970/1970 - 3s - loss: 0.3600 - auc_3: 0.8756 - val_loss: 0.3588 - val_auc_3: 0.8763 - 3s/epoch - 2ms/step
# Epoch 62/100
# 1970/1970 - 3s - loss: 0.3600 - auc_3: 0.8755 - val_loss: 0.3586 - val_auc_3: 0.8763 - 3s/epoch - 2ms/step
# Epoch 63/100
# 1970/1970 - 3s - loss: 0.3597 - auc_3: 0.8756 - val_loss: 0.3587 - val_auc_3: 0.8763 - 3s/epoch - 2ms/step
# Epoch 64/100
# 1970/1970 - 3s - loss: 0.3597 - auc_3: 0.8756 - val_loss: 0.3583 - val_auc_3: 0.8764 - 3s/epoch - 2ms/step
# Epoch 65/100
# 1970/1970 - 3s - loss: 0.3595 - auc_3: 0.8756 - val_loss: 0.3586 - val_auc_3: 0.8765 - 3s/epoch - 2ms/step
# Epoch 66/100
# 1970/1970 - 3s - loss: 0.3594 - auc_3: 0.8757 - val_loss: 0.3582 - val_auc_3: 0.8764 - 3s/epoch - 2ms/step
# Epoch 67/100
# 1970/1970 - 3s - loss: 0.3594 - auc_3: 0.8756 - val_loss: 0.3586 - val_auc_3: 0.8763 - 3s/epoch - 2ms/step
# Epoch 68/100
# 1970/1970 - 3s - loss: 0.3592 - auc_3: 0.8757 - val_loss: 0.3585 - val_auc_3: 0.8764 - 3s/epoch - 2ms/step
# Epoch 69/100
# 1970/1970 - 3s - loss: 0.3591 - auc_3: 0.8758 - val_loss: 0.3578 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 70/100
# 1970/1970 - 3s - loss: 0.3590 - auc_3: 0.8757 - val_loss: 0.3584 - val_auc_3: 0.8762 - 3s/epoch - 2ms/step
# Epoch 71/100
# 1970/1970 - 3s - loss: 0.3590 - auc_3: 0.8758 - val_loss: 0.3579 - val_auc_3: 0.8765 - 3s/epoch - 2ms/step
# Epoch 72/100
# 1970/1970 - 3s - loss: 0.3589 - auc_3: 0.8758 - val_loss: 0.3578 - val_auc_3: 0.8765 - 3s/epoch - 2ms/step
# Epoch 73/100
# 1970/1970 - 3s - loss: 0.3589 - auc_3: 0.8757 - val_loss: 0.3576 - val_auc_3: 0.8765 - 3s/epoch - 2ms/step
# Epoch 74/100
# 1970/1970 - 3s - loss: 0.3587 - auc_3: 0.8759 - val_loss: 0.3580 - val_auc_3: 0.8764 - 3s/epoch - 2ms/step
# Epoch 75/100
# 1970/1970 - 3s - loss: 0.3588 - auc_3: 0.8757 - val_loss: 0.3574 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 76/100
# 1970/1970 - 3s - loss: 0.3586 - auc_3: 0.8759 - val_loss: 0.3573 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 77/100
# 1970/1970 - 3s - loss: 0.3585 - auc_3: 0.8759 - val_loss: 0.3573 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 78/100
# 1970/1970 - 3s - loss: 0.3585 - auc_3: 0.8759 - val_loss: 0.3572 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 79/100
# 1970/1970 - 3s - loss: 0.3583 - auc_3: 0.8759 - val_loss: 0.3576 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 80/100
# 1970/1970 - 3s - loss: 0.3584 - auc_3: 0.8759 - val_loss: 0.3572 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 81/100
# 1970/1970 - 3s - loss: 0.3583 - auc_3: 0.8760 - val_loss: 0.3577 - val_auc_3: 0.8764 - 3s/epoch - 2ms/step
# Epoch 82/100
# 1970/1970 - 3s - loss: 0.3582 - auc_3: 0.8759 - val_loss: 0.3570 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 83/100
# 1970/1970 - 3s - loss: 0.3582 - auc_3: 0.8760 - val_loss: 0.3569 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 84/100
# 1970/1970 - 3s - loss: 0.3581 - auc_3: 0.8760 - val_loss: 0.3571 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 85/100
# 1970/1970 - 3s - loss: 0.3581 - auc_3: 0.8759 - val_loss: 0.3570 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 86/100
# 1970/1970 - 3s - loss: 0.3579 - auc_3: 0.8760 - val_loss: 0.3567 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 87/100
# 1970/1970 - 3s - loss: 0.3578 - auc_3: 0.8761 - val_loss: 0.3565 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 88/100
# 1970/1970 - 3s - loss: 0.3577 - auc_3: 0.8760 - val_loss: 0.3565 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 89/100
# 1970/1970 - 3s - loss: 0.3576 - auc_3: 0.8761 - val_loss: 0.3565 - val_auc_3: 0.8769 - 3s/epoch - 2ms/step
# Epoch 90/100
# 1970/1970 - 3s - loss: 0.3576 - auc_3: 0.8761 - val_loss: 0.3565 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step
# Epoch 91/100
# 1970/1970 - 3s - loss: 0.3576 - auc_3: 0.8761 - val_loss: 0.3571 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 92/100
# 1970/1970 - 3s - loss: 0.3575 - auc_3: 0.8761 - val_loss: 0.3565 - val_auc_3: 0.8766 - 3s/epoch - 2ms/step
# Epoch 93/100
# 1970/1970 - 3s - loss: 0.3575 - auc_3: 0.8760 - val_loss: 0.3563 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 94/100
# 1970/1970 - 3s - loss: 0.3575 - auc_3: 0.8761 - val_loss: 0.3563 - val_auc_3: 0.8767 - 3s/epoch - 2ms/step
# Epoch 95/100
# 1970/1970 - 3s - loss: 0.3573 - auc_3: 0.8761 - val_loss: 0.3561 - val_auc_3: 0.8769 - 3s/epoch - 2ms/step
# Epoch 96/100
# 1970/1970 - 3s - loss: 0.3574 - auc_3: 0.8760 - val_loss: 0.3561 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step
# Epoch 97/100
# 1970/1970 - 3s - loss: 0.3572 - auc_3: 0.8762 - val_loss: 0.3562 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step
# Epoch 98/100
# 1970/1970 - 3s - loss: 0.3572 - auc_3: 0.8762 - val_loss: 0.3565 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step
# Epoch 99/100
# 1970/1970 - 3s - loss: 0.3571 - auc_3: 0.8762 - val_loss: 0.3561 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step
# Epoch 100/100
# 1970/1970 - 3s - loss: 0.3572 - auc_3: 0.8761 - val_loss: 0.3568 - val_auc_3: 0.8768 - 3s/epoch - 2ms/step

# %%
fig = plt.figure(figsize=(12, 6), dpi=100)
plt.plot(history3.history["val_loss"], label="validation loss")
plt.plot(history3.history["loss"], label="training loss")
plt.xlabel("Epoch", weight="bold", fontsize=16)
plt.ylabel("Loss", weight="bold", fontsize=16)
plt.legend()

# %% [markdown]
# # Evaluacion del modelo final
# Vemos que el que obtuvo un mejor score es el modelo 2. Evaluamos el modelo con las siguientes métricas:

# %%
X_eval = preprocessing_redes_1(X_eval)

y_pred = model2.predict(X_eval)

print(f"Auc Roc: {roc_auc_score(y_eval, y_pred)}")
print(f"Accuracy: {accuracy_score(y_eval, y_pred.round())}")
print(f"Precision: {precision_score(y_eval, y_pred.round())}")
print(f"Recall: {recall_score(y_eval, y_pred.round())}")
print(f"F1 Score: {f1_score(y_eval, y_pred.round())}")
# Out:
# Auc Roc: 0.8999452503200893
# Accuracy: 0.8682921954631758
# Precision: 0.7474972191323693
# Recall: 0.6086956521739131
# F1 Score: 0.6709935097353971

# %%
fpr, tpr, thresholds = roc_curve(y_eval, y_pred)
roc_auc = auc(fpr, tpr)
display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6c/nfvy02l96fnfjc47g2wy41s80000gn/T/ipykernel_15684/3365050663.py in <module>
#       1 fpr, tpr, thresholds = roc_curve(y_eval, y_pred)
#       2 roc_auc = auc(fpr, tpr)
# ----> 3 display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
#       4 display.plot()
#       5 plt.show()
#
# NameError: name 'RocCurveDisplay' is not defined

# %% [markdown]
# # Predicciones finales

# %%
X_train, X_test, y_train, y_test = preprocessing_redes_1(df)

with requests.get(
    "https://docs.google.com/spreadsheets/d/1mR_JNN0-ceiB5qV42Ff9hznz0HtWaoPF3B9zNGoNPY8/export?format=csv") as r, open("pred.csv", "wb") as f:
    for chunk in r.iter_content():
        f.write(chunk)

df_pred = pd.read_csv("pred.csv")

# %%
df_pred_preprocess = preprocessing_redes_pred(df_pred)
y_pred_final = np.rint(model2.predict(df_pred_preprocess)).astype('int').flatten()

# %%
df_pred_final = pd.DataFrame({'id': df_pred['id'], 'llovieron_hamburguesas_al_dia_siguiente': y_pred_final})
df_pred_final.loc[df_pred_final['llovieron_hamburguesas_al_dia_siguiente'] == 1, 'llovieron_hamburguesas_al_dia_siguiente'] = 'si'
df_pred_final.loc[df_pred_final['llovieron_hamburguesas_al_dia_siguiente'] == 0, 'llovieron_hamburguesas_al_dia_siguiente'] = 'no'

df_pred_final
# Out:
#            id llovieron_hamburguesas_al_dia_siguiente
# 0      116706                                      no
# 1       58831                                      no
# 2       31981                                      no
# 3        2533                                      no
# 4        7270                                      si
# ...       ...                                     ...
# 29087   73456                                      no
# 29088   14471                                      no
# 29089  106482                                      no
# 29090   21057                                      no
# 29091  102055                                      no
#
# [29092 rows x 2 columns]

# %%
df_pred_final.to_csv('predicciones/redes_neuronales.csv', index=False)
